# %%
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from nba_api.stats.endpoints import boxscoreadvancedv2
from nba_api.stats.endpoints import boxscoresummaryv2
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.endpoints import boxscoremiscv2
from nba_api.stats.endpoints import boxscorefourfactorsv2
from nba_api.stats.endpoints import boxscoretraditionalv2
from nba_api.stats.endpoints import boxscoreusagev2
import matplotlib.pyplot as plt
from keras import backend as K
from sklearn import preprocessing
import tensorflow as tf
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import BaggingRegressor,BaggingClassifier, RandomForestRegressor,RandomForestClassifier
from sklearn.metrics import mean_squared_error,r2_score,roc_curve,auc
from sklearn.preprocessing import MinMaxScaler
# Out:
# 2022-11-14 13:05:32.602639: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Out:
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
# ...
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(merged)
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(merged)
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(merged)
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Odds_A'] = odds_convert(y['Pinnacle_ML_A'])
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Odds_B'] = odds_convert(y['Pinnacle_ML_B'])
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['y_true'] = y.apply(lambda row : get_y_true(row['Result_A'],
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/3822372732.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train2['b_win'] = abs(1-y_train2['a_win'])
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/3822372732.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test2['b_win'] = abs(1-y_test2['a_win'])
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/3822372732.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train2['no_bet'] = 0
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/3822372732.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test2['no_bet'] = 0

# %%
nba_teams = ['Cleveland Cavaliers','Boston Celtics','Golden State Warriors','Houston Rockets','Utah Jazz'
             ,'Philadelphia 76ers','Toronto Raptors','New Orleans Pelicans','Washington Wizards','Miami Heat'
            ,'Milwaukee Bucks','Indiana Pacers','Oklahoma City Thunder','San Antonio Spurs','Portland Trail Blazers',
             'Minnesota Timberwolves','Chicago Bulls','Dallas Mavericks','Sacramento Kings','Los Angeles Lakers'
            ,'Orlando Magic','Denver Nuggets','LA Clippers','New York Knicks','Memphis Grizzlies','Detroit Pistons'
            ,'Charlotte Hornets','Atlanta Hawks','Phoenix Suns','Brooklyn Nets']
# Out:
#      FG_PCT_median_A  FG3_PCT_median_A  FT_PCT_median_A  PTS_per_minute_A  \
# 0             0.4550            0.3470           0.7340          2.204082
# 1             0.4410            0.3285           0.7815          2.102564
# 2             0.4540            0.3600           0.8000          2.159215
# 3             0.4635            0.3515           0.7815          2.121026
# 4             0.4690            0.3570           0.7740          2.115880
# ..               ...               ...              ...               ...
# 799           0.4860            0.3425           0.8170          2.346930
# 800           0.4540            0.3655           0.8260          2.327296
# 801           0.4570            0.3460           0.6920          2.328737
# 802           0.4710            0.3830           0.7930          2.374211
# 803           0.4370            0.3515           0.7405          2.270965
#
#      FGM_per_minute_A  FGA_per_minute_A  FG3M_per_minute_A  FG3A_per_minute_A  \
# 0            0.832653          1.813265           0.182653           0.524490
# 1            0.786667          1.757949           0.160000           0.497436
# 2            0.825518          1.847328           0.188659           0.527808
# 3            0.772308          1.701538           0.170256           0.486154
# 4            0.816524          1.791845           0.160944           0.458155
# ..                ...               ...                ...                ...
# 799          0.875912          1.847145           0.233147           0.679261
# 800          0.858560          1.862441           0.226391           0.630013
# 801          0.872776          1.911922           0.209075           0.621886
# 802          0.853472          1.810640           0.197475           0.510821
# 803          0.803427          1.790803           0.249775           0.722272
#
#      FTM_per_minute_A  FTA_per_minute_A  ...  E_PACE_median_B  PACE_median_B  \
# 0            0.356122          0.486735  ...           99.315         96.705
# 1            0.369231          0.480000  ...          101.455         99.085
# 2            0.319520          0.407852  ...           98.190         94.595
# 3            0.406154          0.521026  ...           99.300         97.000
# 4            0.321888          0.409871  ...           97.860         96.000
# ..                ...               ...  ...              ...            ...
# 799          0.361958          0.451696  ...          106.140        104.000
# 800          0.383786          0.471755  ...          105.560        103.000
# 801          0.374110          0.523132  ...          100.830         99.500
# 802          0.469793          0.590622  ...          101.890        100.740
# 803          0.414337          0.555906  ...          103.290        101.750
#
#      PACE_PER40_median_B  POSS_median_B  PIE_median_B  FTA_RATE_median_B  \
# 0                 80.585           99.5        0.4775             0.2510
# 1                 82.570           99.0        0.5130             0.2735
# 2                 78.830           97.0        0.4705             0.2890
# 3                 80.830           97.0        0.4800             0.2040
# 4                 80.000           96.0        0.5790             0.3650
# ..                   ...            ...           ...                ...
# 799               86.670          104.0        0.4870             0.2330
# 800               85.830          104.0        0.5215             0.2720
# 801               82.920           99.0        0.5230             0.2510
# 802               83.950          101.0        0.4725             0.2840
# 803               84.790          102.0        0.5105             0.3295
#
#      OPP_EFG_PCT_median_B  OPP_FTA_RATE_median_B  OPP_TOV_PCT_median_B  \
# 0                  0.4860                 0.2390                0.1290
# 1                  0.4975                 0.2650                0.1335
# 2                  0.5090                 0.3095                0.1530
# 3                  0.5050                 0.3020                0.1410
# 4                  0.4870                 0.2620                0.1610
# ..                    ...                    ...                   ...
# 799                0.5290                 0.2820                0.1560
# 800                0.5075                 0.2545                0.1660
# 801                0.5135                 0.2455                0.1220
# 802                0.5255                 0.2305                0.1290
# 803                0.5140                 0.2780                0.1175
#
#      OPP_OREB_PCT_median_B
# 0                   0.2655
# 1                   0.2675
# 2                   0.2705
# 3                   0.2750
# 4                   0.2800
# ..                     ...
# 799                 0.3000
# 800                 0.2645
# 801                 0.2550
# 802                 0.2510
# 803                 0.2785
#
# [4500 rows x 96 columns]

# %%
def feature_clean(features):
    for columnName in features:
        if ((columnName[0:4] == 'TEAM') | (columnName[0:4] == 'GAME')):
            features = features.drop(columns = [columnName])
    return features

# %%
def combine_team_games(df, keep_method='home'):
    '''Combine a TEAM_ID-GAME_ID unique table into rows by game. Slow.

        Parameters
        ----------
        df : Input DataFrame.
        keep_method : {'home', 'away', 'winner', 'loser', ``None``}, default 'home'
            - 'home' : Keep rows where TEAM_A is the home team.
            - 'away' : Keep rows where TEAM_A is the away team.
            - 'winner' : Keep rows where TEAM_A is the losing team.
            - 'loser' : Keep rows where TEAM_A is the winning team.
            - ``None`` : Keep all rows. Will result in an output DataFrame the same
                length as the input DataFrame.
                
        Returns
        -------
        result : DataFrame
    '''
    # Join every row to all others with the same game ID.
    joined = pd.merge(df, df, suffixes=['_A', '_B'],
                      on=['GAME_ID'])
    # Filter out any row that is joined to itself.
    
    for columnName in joined:
        if(columnName == 'TEAM_ID_A_x'):
            joined = joined.rename(columns = {'TEAM_ID_A_x':'TEAM_ID_A'})
        
    for columnName in joined:
        if(columnName == 'TEAM_ID_B_x'):
            joined = joined.rename(columns = {'TEAM_ID_B_x':'TEAM_ID_B'})  
        
    result = joined[joined.TEAM_ID_A != joined.TEAM_ID_B]
    # Take action based on the keep_method flag.
    if keep_method is None:
        # Return all the rows.
        pass
    elif keep_method.lower() == 'home':
        # Keep rows where TEAM_A is the home team.
        result = result[result.MATCHUP_A.str.contains(' vs. ')]
    elif keep_method.lower() == 'away':
        # Keep rows where TEAM_A is the away team.
        result = result[result.MATCHUP_A.str.contains(' @ ')]
    elif keep_method.lower() == 'winner':
        result = result[result.WL_A == 'W']
    elif keep_method.lower() == 'loser':
        result = result[result.WL_A == 'L']
    else:
        raise ValueError(f'Invalid keep_method: {keep_method}')
    return result

# %%
def combine_vegas_games(df):
    '''Combine a TEAM_ID-GAME_ID unique table into rows by game. Slow.

        Parameters
        ----------
        df : Input DataFrame.
        keep_method : {'home', 'away', 'winner', 'loser', ``None``}, default 'home'
            - 'home' : Keep rows where TEAM_A is the home team.
            - 'away' : Keep rows where TEAM_A is the away team.
            - 'winner' : Keep rows where TEAM_A is the losing team.
            - 'loser' : Keep rows where TEAM_A is the winning team.
            - ``None`` : Keep all rows. Will result in an output DataFrame the same
                length as the input DataFrame.
                
        Returns
        -------
        result : DataFrame
    '''
    # Join every row to all others with the same game ID.
    joined = pd.merge(df, df, suffixes=['_A', '_B'],
                      on=['GameId'])
    # Filter out any row that is joined to itself.
    
    result = joined[joined.TeamId_A != joined.TeamId_B]
    # Take action based on the keep_method flag.
    return result

# %%
team_ids
# Out:
# Int64Index([1610612752, 1610612739, 1610612741, 1610612737, 1610612764,
#             1610612747, 1610612745, 1610612758, 1610612756, 1610612755,
#             1610612760, 1610612740, 1610612743, 1610612750, 1610612763,
#             1610612749, 1610612766, 1610612761, 1610612765, 1610612751,
#             1610612738, 1610612742, 1610612754, 1610612753, 1610612748,
#             1610612744, 1610612759, 1610612762, 1610612757, 1610612746],
#            dtype='int64')

# %%
def remove_unnamed(frame):
    for columnName in frame:
        if(columnName[0:7] == 'Unnamed'):
            frame = frame.drop(columns = [columnName])
    return frame

# %%
def pull_reg_season(start_year, start_date, end_date):
    reg = pd.DataFrame()
    for i in team_ids:
        games_base = leaguegamefinder.LeagueGameFinder(team_id_nullable = i)
        games_xxxx = games_base.get_data_frames()[0]
        games_xxxx = games_xxxx[games_xxxx.TEAM_NAME.isin(nba_teams)]
        regular_xxxx = games_xxxx[(games_xxxx.GAME_DATE > start_date) & (games_xxxx.GAME_DATE < end_date)]
        reg = reg.append(regular_xxxx)
        time.sleep(30)
    reg = reg.sort_values('GAME_ID')
    return reg

# %%
def pull_stats(api, index, ids):
    box = pd.DataFrame()
    subset1 = ids[0:308]
    subset2 = ids[308:616]
    subset3 = ids[616:924]
    subset4 = ids[924:1231]
    subset_list = [subset1, subset2, subset3, subset4]
    for i in subset_list:
        for j in i:
            print(j)
            row = api(game_id = j)
            row = row.get_data_frames()[index]
            row['GAME_ID'] = j
            row = combine_team_games(row, keep_method = None)
            box = box.append(row)
        time.sleep(60)
    return box

# %%
def pull_stats_slow(api, index, ids):
    box = pd.DataFrame()
    subset1 = ids[0:77]
    subset2 = ids[77:154]
    subset3 = ids[154:231]
    subset4 = ids[231:308]
    subset5 = ids[308:385]
    subset6 = ids[385:462]
    subset7 = ids[462:539]
    subset8 = ids[539:616]
    subset9 = ids[616:693]
    subset10 = ids[693:770]
    subset11 = ids[770:847]
    subset12 = ids[847:924]
    subset13= ids[924:1001]
    subset14 = ids[1001:1078]
    subset15 = ids[1078:1155]
    subset16 = ids[1155:1231]
    subset_list = [subset1, subset2, subset3, subset4,subset5, subset6, subset7, subset8,
                  subset9, subset10, subset11, subset12,subset13, subset14, subset15, subset16]
    counter = 0
    for i in subset_list:
        for j in i:
            row = api(game_id = j)
            row = row.get_data_frames()[index]
            row['GAME_ID'] = j
            row = combine_team_games(row, keep_method = None)
            box = box.append(row)
            print(counter)
            counter = counter + 1
            time.sleep(1)
        time.sleep(150)
    return box

# %%
def pull_stats_super_slow(api, index, reg_season):
    box = pd.DataFrame()
    reg_season = reg_season.drop_duplicates(subset = ['GAME_ID'])
    ids = reg_season['GAME_ID']
    subset1 = ids[0:308]
    subset2 = ids[308:616]
    subset3 = ids[616:924]
    subset4 = ids[924:1231]
    subset_list = [subset1, subset2, subset3, subset4]
    for i in subset_list:
        for j in i:
            row = api(game_id = j)
            row = row.get_data_frames()[index]
            row['GAME_ID'] = j
            row = combine_team_games(row, keep_method = None)
            box = box.append(row)
            time.sleep(10)
    return box

# %%
def home_away(matchup):
    if(matchup[4] == '@'):
        return 0
    else:
        return 1

# %%
def reg_clean(reg):
    reg['home'] = reg.apply(lambda row : home_away(row['MATCHUP']), axis = 1)
    if(('GAME_ID')[0] == '0'):
        reg['GAME_ID'] = reg['GAME_ID'].str[2:].astype(int)
    reg = reg.sort_values('GAME_ID')
    reg = combine_team_games(reg,keep_method=None)
    return reg

# %%
def home_win(WL_A):
    if(WL_A == 'W'):
        return([1,0,0])
    else:
        return([0,1,0])

# %%
def adv_clean(advanced):
    advanced = advanced.drop(columns = ['TEAM_ID_B','TEAM_ABBREVIATION_A','TEAM_ABBREVIATION_B'
                                   ,'TEAM_CITY_A','TEAM_CITY_B','TEAM_NAME_A','TEAM_NAME_B','MIN_A'])
    advanced = advanced.sort_values('GAME_ID')
    return advanced

# %%
def traditional_clean(traditional):
    bench = traditional.drop_duplicates(subset = ['GAME_ID','TEAM_NAME_A'], keep = 'last')
    starters = traditional.drop_duplicates(subset = ['GAME_ID','TEAM_NAME_A'], keep = 'first')
    bench = bench.drop(columns = ['TEAM_NAME_A', 'TEAM_ABBREVIATION_A',
       'TEAM_CITY_A', 'STARTERS_BENCH_A', 'MIN_A','TEAM_ID_B', 'TEAM_NAME_B',
       'TEAM_ABBREVIATION_B', 'TEAM_CITY_B', 'STARTERS_BENCH_B', 'MIN_B'])
    starters = starters.drop(columns = ['TEAM_NAME_A', 'TEAM_ABBREVIATION_A',
       'TEAM_CITY_A', 'STARTERS_BENCH_A', 'MIN_A','TEAM_ID_B', 'TEAM_NAME_B',
       'TEAM_ABBREVIATION_B', 'TEAM_CITY_B', 'STARTERS_BENCH_B', 'MIN_B'])
    for columnName in bench:
        if((columnName == 'GAME_ID') | (columnName == 'TEAM_ID_A')):
            continue
        new_col_name = columnName + '_bench'
        bench[new_col_name] = bench[columnName]
        bench = bench.drop(columns = [columnName])
    for columnName in starters:
        if((columnName == 'GAME_ID') | (columnName == 'TEAM_ID_A')):
            continue
        new_col_name = columnName + '_starters'
        starters[new_col_name] = starters[columnName]
        starters = starters.drop(columns = [columnName])
        
    merged = pd.merge(starters,bench,left_on = 'GAME_ID',right_on = 'GAME_ID')
    merged = merged.drop_duplicates(subset = ['GAME_ID','TEAM_ID_A_x'])
    merged = merged.drop(columns = ['TEAM_ID_A_y'])
    merged = merged.rename(columns={"TEAM_ID_A_x": "TEAM_ID_A"})
    return(merged)

# %%
def four_clean(four):
    four = four.drop(columns = ['TEAM_NAME_A', 'TEAM_ABBREVIATION_A',
       'TEAM_CITY_A', 'MIN_A','TEAM_ABBREVIATION_B',
       'TEAM_CITY_B', 'MIN_B','OREB_PCT_A','TM_TOV_PCT_A','EFG_PCT_A'])
    four = four.sort_values('GAME_ID')
    return four

# %%
def usage_clean(usage):
    return usage

# %%
def misc_clean(misc):
    misc = misc.drop(columns = ['TEAM_NAME_A', 'TEAM_ABBREVIATION_A',
       'TEAM_CITY_A', 'MIN_A'])
    return misc

# %%
def get_minutes(matchupmisc):
    matchupmisc = matchupmisc.reset_index(drop=True)
    matchupmisc = matchupmisc.sort_values('GAME_ID')
    matchupmisc['minutes'] = (matchupmisc['MIN_A'].str[0:3].astype(int))/5
    minutes =  matchupmisc['minutes']
    return minutes

# %%
def per_minute_stats(frame, minutes):
    frame = frame.reset_index(drop = True)
    features = frame.drop(columns = ['GAME_ID'])
    game_id = frame['GAME_ID'].reset_index(drop = True)
    team_id = frame['TEAM_ID_A'].reset_index(drop=True)
    for columnName in features:
        if(columnName[-1] == 'B'):
            features = features.drop(columns = [columnName])
    for columnName in features:
        if(columnName[-1] == 'A'):
            features = features.rename(columns={columnName: columnName[0:-2]})
    features['minutes'] = minutes
    cumulative = features.groupby('TEAM_ID').cumsum()
    for columnName in cumulative:
        if((columnName == 'minutes') | (columnName == 'TEAM_ID')):
            continue
        new_col_name = columnName + '_per_minute'
        features[new_col_name] = ((cumulative[columnName] - features[columnName]) / (cumulative['minutes'] - features['minutes']))
        features = features.drop(columns = [columnName])
    features = features.reset_index(drop= True)
    features= features.drop(columns = ['minutes'])
    features['TEAM_ID'] = team_id
    features['GAME_ID'] = game_id
    return combine_team_games(features, keep_method = None)

# %%
def cum_stats(frame):
    frame = frame.reset_index(drop = True)
    features = frame.drop(columns = ['GAME_ID'])
    game_id = frame['GAME_ID'].reset_index(drop = True)
    team_id = frame['TEAM_ID_A'].reset_index(drop=True)
    for columnName in features:
        if(columnName[-1] == 'B'):
            features = features.drop(columns = [columnName])
    for columnName in features:
        if(columnName[-1] == 'A'):
            features = features.rename(columns={columnName: columnName[0:-2]})
    features = features.reset_index(drop = True)
    for columnName in features:
        if(columnName == 'TEAM_ID'):
            continue
        new_col_name = columnName + '_median'
        features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
        features = features.drop(columns = [columnName])
    features = features.reset_index(drop= True)
    features['TEAM_ID'] = team_id
    features['GAME_ID'] = game_id
    features = features.reset_index(drop = True)
    return combine_team_games(features, keep_method = None)

# %%
def reg_impute(reg_cleaned, minutes):
    per_minute = reg_cleaned[['TEAM_ID_A', 'GAME_ID', 'PTS_A', 'FGM_A', 'FGA_A',
                      'FG3M_A','FG3A_A','FTM_A', 'FTA_A','OREB_A', 'DREB_A',
       'REB_A', 'AST_A', 'STL_A', 'BLK_A', 'TOV_A', 'PF_A', 'PLUS_MINUS_A']]
    
    cum = reg_cleaned[['TEAM_ID_A', 'GAME_ID','FG_PCT_A','FG3_PCT_A','FT_PCT_A']]
    home = reg_cleaned[['TEAM_ID_A','GAME_ID','home_A']]
    
    per_minute = per_minute_stats(per_minute, minutes)
    cum = cum_stats(cum)
    merged = pd.merge(cum,per_minute,left_on = ['GAME_ID','TEAM_ID_A'],right_on=['GAME_ID','TEAM_ID_A'])
    merged = pd.merge(merged,home,left_on = ['GAME_ID','TEAM_ID_A'],right_on=['GAME_ID','TEAM_ID_A'])
    #merged = merged.drop_duplicates(subset = ['TEAM_ID_A_x','GAME_ID','TEAM_ID_B_x'])
    merged = merged.rename(columns = {'TEAM_ID_A_x':'TEAM_ID'})
    for columnName in merged:
        if(columnName[-1] == 'B'):
            merged = merged.drop(columns = [columnName])
    for columnName in merged:
        if(columnName[-1] == 'A'):
            merged = merged.rename(columns={columnName: columnName[0:-2]})
    merged = merged.drop(columns = ['TEAM_ID_B_x','TEAM_ID_B_y'])
    merged = combine_team_games(merged,keep_method = None)
    #return merged
    #merged['GAME_ID'] = merged['GAME_ID'].str[2:].astype(int)
    return merged

# %%
def get_62(frame):
    return frame.iloc[600:,:]

# %%
def four_impute(four_cleaned):
    cum = cum_stats(four_cleaned)
    #cum['GAME_ID'] = cum['GAME_ID'].str[2:].astype(int)
    return cum

# %%
def adv_impute(advanced_cleaned):
    cum = cum_stats(advanced_cleaned)
    return cum

# %%
def merger(reg_imputed, advanced_imputed, four_imputed):
    merged = pd.merge(reg_imputed,advanced_imputed, left_on = ['GAME_ID','TEAM_ID_A'],right_on = ['GAME_ID','TEAM_ID_A'])
    merged = pd.merge(merged,four_imputed, left_on = ['GAME_ID','TEAM_ID_A'],right_on = ['GAME_ID','TEAM_ID_A'])
    return get_62(merged)

# %%
def current_merger(reg_imputed, advanced_imputed, four_imputed):
    merged = pd.merge(reg_imputed,advanced_imputed, left_on = ['GAME_ID','TEAM_ID_A'],right_on = ['GAME_ID','TEAM_ID_A'])
    merged = pd.merge(merged,four_imputed, left_on = ['GAME_ID','TEAM_ID_A'],right_on = ['GAME_ID','TEAM_ID_A'])
    return merged

# %%
def dataload_clean(year,start_date,end_date):
    reg = pull_reg_season(year,start_date,end_date)
    misc = pull_stats_slow(boxscoremiscv2.BoxScoreMiscV2,1,reg)
    minutes = get_minutes(misc)
    advanced = pull_stats_slow(boxscoreadvancedv2.BoxScoreAdvancedV2,1,reg)
    four = pull_stats_slow(boxscorefourfactorsv2.BoxScoreFourFactorsV2,1,reg)
    merged = merger(reg_impute(reg_clean(reg), minutes),advanced_impute(advancedboxscore_clean(advanced)),
                    four_impute(four_factors_clean(four)))
    merged.to_csv(year + '.csv')
    return merged

# %%
def dataloader(year,start_date,end_date):
    reg = pull_reg_season(year,start_date,end_date)
    reg.to_csv('reg' + year + '.csv')
    misc = pull_stats(boxscoremiscv2.BoxScoreMiscV2,1,get_ids(reg))
    misc.to_csv('misc' + year + '.csv')
    adv = pull_stats(boxscoreadvancedv2.BoxScoreAdvancedV2,1,get_ids(reg))
    adv.to_csv('adv' + year + '.csv')
    four = pull_stats(boxscorefourfactorsv2.BoxScoreFourFactorsV2,1,get_ids(reg))
    four.to_csv('four' + year + '.csv')
    return[reg,misc,adv,four]

# %%
def get_ids(reg):
    unique = reg.drop_duplicates('GAME_ID')
    return unique['GAME_ID']

# %%
def add_zeros(game_id):
    new_id = '00' + (str(game_id))
    return new_id

# %%
def get_A_features(frame):
    new = frame
    for columnName in frame:
        if(columnName[-1] == 'B'):
            new = new.drop(columns=[columnName])
            
    return new

# %%
def order_features(frame):
    counter = 1
    new = []
    for columnName in frame:
        if(columnName[-1] == 'A'):
            new.append(columnName)
    for columnName in frame:
        if(columnName[-1] == 'B'):
            new.append(columnName)
    return frame[new]

# %%
#reg2 = reg_impute(reg_clean(current),get_minutes(misc22))
#adv2 = adv_impute(adv_clean(adv22))
#four2 = four_impute(four_clean(four22))
#merged = pd.merge(reg2,adv2, left_on = ['GAME_ID','TEAM_ID_A'],right_on = ['GAME_ID','TEAM_ID_A'])
#merged = pd.merge(merged,four2, left_on = ['GAME_ID','TEAM_ID_A'],right_on = ['GAME_ID','TEAM_ID_A'])
    #merged = feature_clean(merged)
#merged = remove_unnamed(merged)

# %%
#features = []
#for i in team_ids:
#    temp = merged[merged['TEAM_ID_A'] == i]
#    features.append(temp.iloc[-1,:])

# %%
#reg16[reg16['TEAM_NAME'] == 'Miami Heat']

# %%
reg22
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 reg22
#
# NameError: name 'reg22' is not defined

# %%
november = pd.read_csv('schedule/11.csv')

# %%
november
# Out:
#                 Date Start (ET)         Visitor/Neutral    PTS  \
# 0     Tue Nov 1 2022      7:30p           Chicago Bulls  108.0
# 1     Tue Nov 1 2022      7:30p   Golden State Warriors  109.0
# 2     Tue Nov 1 2022      8:00p           Orlando Magic  108.0
# 3     Tue Nov 1 2022     10:00p  Minnesota Timberwolves  107.0
# 4     Wed Nov 2 2022      6:00p      Washington Wizards  121.0
# ..               ...        ...                     ...    ...
# 217  Wed Nov 30 2022      9:00p         Houston Rockets    NaN
# 218  Wed Nov 30 2022      9:00p           Chicago Bulls    NaN
# 219  Wed Nov 30 2022      9:00p    Los Angeles Clippers    NaN
# 220  Wed Nov 30 2022     10:00p          Indiana Pacers    NaN
# 221  Wed Nov 30 2022     10:30p  Portland Trail Blazers    NaN
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  \
# 0            Brooklyn Nets   99.0  Box Score        NaN  17732.0
# 1               Miami Heat  116.0  Box Score        NaN  19600.0
# 2    Oklahoma City Thunder  116.0  Box Score        NaN  13109.0
# 3             Phoenix Suns  116.0  Box Score        NaN  17071.0
# 4       Philadelphia 76ers  111.0  Box Score        NaN  19855.0
# ..                     ...    ...        ...        ...      ...
# 217         Denver Nuggets    NaN        NaN        NaN      NaN
# 218           Phoenix Suns    NaN        NaN        NaN      NaN
# 219              Utah Jazz    NaN        NaN        NaN      NaN
# 220       Sacramento Kings    NaN        NaN        NaN      NaN
# 221     Los Angeles Lakers    NaN        NaN        NaN      NaN
#
#                   Arena  Notes
# 0       Barclays Center    NaN
# 1             FTX Arena    NaN
# 2         Paycom Center    NaN
# 3      Footprint Center    NaN
# 4    Wells Fargo Center    NaN
# ..                  ...    ...
# 217          Ball Arena    NaN
# 218    Footprint Center    NaN
# 219        Vivint Arena    NaN
# 220     Golden 1 Center    NaN
# 221    Crypto.com Arena    NaN
#
# [222 rows x 11 columns]

# %%
reg22
# Out:
#      Unnamed: 0  SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0             8      22022  1610612755               PHI
# 1             6      22022  1610612738               BOS
# 2             6      22022  1610612747               LAL
# 3             8      22022  1610612744               GSW
# 4             8      22022  1610612765               DET
# ..          ...        ...         ...               ...
# 233           0      22022  1610612747               LAL
# 234           0      22022  1610612744               GSW
# 235           0      22022  1610612753               ORL
# 236           0      22022  1610612760               OKC
# 237           0      22022  1610612743               DEN
#
#                  TEAM_NAME   GAME_ID   GAME_DATE      MATCHUP WL  MIN  ...  \
# 0       Philadelphia 76ers  22200001  2022-10-18    PHI @ BOS  L  239  ...
# 1           Boston Celtics  22200001  2022-10-18  BOS vs. PHI  W  240  ...
# 2       Los Angeles Lakers  22200002  2022-10-18    LAL @ GSW  L  241  ...
# 3    Golden State Warriors  22200002  2022-10-18  GSW vs. LAL  W  241  ...
# 4          Detroit Pistons  22200003  2022-10-19  DET vs. ORL  W  239  ...
# ..                     ...       ...         ...          ... ..  ...  ...
# 233     Los Angeles Lakers  22200117  2022-11-02  LAL vs. NOP  W  264  ...
# 234  Golden State Warriors  22200118  2022-11-03    GSW @ ORL  L  239  ...
# 235          Orlando Magic  22200118  2022-11-03  ORL vs. GSW  W  240  ...
# 236  Oklahoma City Thunder  22200119  2022-11-03  OKC vs. DEN  L  240  ...
# 237         Denver Nuggets  22200119  2022-11-03    DEN @ OKC  W  240  ...
#
#      OREB  DREB   REB  AST   STL  BLK  TOV  PF  PLUS_MINUS  home
# 0     4.0  27.0  31.0   16   8.0    3   14  25        -9.0     0
# 1     6.0  30.0  36.0   24   8.0    3   10  24         9.0     1
# 2     9.0  39.0  48.0   23  12.0    4   21  18       -14.0     0
# 3    11.0  37.0  48.0   31  11.0    4   18  23        14.0     1
# 4    12.0  29.0  41.0   31  11.0    4   12  21         4.0     1
# ..    ...   ...   ...  ...   ...  ...  ...  ..         ...   ...
# 233  11.0  45.0  56.0   30   6.0    8   17  17         3.0     1
# 234   9.0  26.0  35.0   31   5.0    3   14  32        -1.0     0
# 235  11.0  35.0  46.0   20   9.0    6   19  22         1.0     1
# 236  10.0  30.0  40.0   19   9.0    5   10  19       -12.0     1
# 237   8.0  39.0  47.0   32   5.0    2   18  15        12.0     0
#
# [238 rows x 30 columns]

# %%
#frame1 = pd.DataFrame()
#frame2 = pd.DataFrame()
#for i in current_features:
 #   if(i.TEAM_ID_A == 1610612755):
  #      stats1 = i
   # if(i.TEAM_ID_A == 1610612738):
    #    stats2 = i
#frame1 = frame1.append(stats1)
#frame2 = frame2.append(stats2)
#frame1 = get_A_features(frame1)
#frame2 = get_A_features(frame2)
#frame1 = frame1.reset_index(drop=True)
#frame2 = frame2.reset_index(drop=True)
#merged = frame1.join(frame2,lsuffix='1',rsuffix='2')

# %%
#feature_clean(get_matchup_features(1610612755,1610612738,current_features))[['home_A1','home_A2']]
# Out:
#    home_A1  home_A2
# 0      1.0      0.0

# %%
#(1610612755,1610612738,current_features)
# Out:
#    FG_PCT_median_A1  FG3_PCT_median_A1  FT_PCT_median_A1  PTS_per_minute_A1  \
# 0             0.497             0.4105            0.8305           2.299479
#
#    FGM_per_minute_A1  FGA_per_minute_A1  FG3M_per_minute_A1  \
# 0           0.830729           1.692708            0.273438
#
#    FG3A_per_minute_A1  FTM_per_minute_A1  FTA_per_minute_A1  ...  \
# 0            0.690104           0.364583           0.453125  ...
#
#    E_PACE_median_A2  PACE_median_A2  PACE_PER40_median_A2  POSS_median_A2  \
# 0           100.005           98.11                81.755            98.5
#
#    PIE_median_A2  FTA_RATE_median_A2  OPP_EFG_PCT_median_A2  \
# 0         0.5245              0.2875                 0.5465
#
#    OPP_FTA_RATE_median_A2  OPP_TOV_PCT_median_A2  OPP_OREB_PCT_median_A2
# 0                  0.2875                 0.1195                   0.303
#
# [1 rows x 96 columns]

# %%
november
# Out:
#                 Date Start (ET)         Visitor/Neutral    PTS  \
# 0     Tue Nov 1 2022      7:30p           Chicago Bulls  108.0
# 1     Tue Nov 1 2022      7:30p   Golden State Warriors  109.0
# 2     Tue Nov 1 2022      8:00p           Orlando Magic  108.0
# 3     Tue Nov 1 2022     10:00p  Minnesota Timberwolves  107.0
# 4     Wed Nov 2 2022      6:00p      Washington Wizards  121.0
# ..               ...        ...                     ...    ...
# 217  Wed Nov 30 2022      9:00p         Houston Rockets    NaN
# 218  Wed Nov 30 2022      9:00p           Chicago Bulls    NaN
# 219  Wed Nov 30 2022      9:00p    Los Angeles Clippers    NaN
# 220  Wed Nov 30 2022     10:00p          Indiana Pacers    NaN
# 221  Wed Nov 30 2022     10:30p  Portland Trail Blazers    NaN
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  \
# 0            Brooklyn Nets   99.0  Box Score        NaN  17732.0
# 1               Miami Heat  116.0  Box Score        NaN  19600.0
# 2    Oklahoma City Thunder  116.0  Box Score        NaN  13109.0
# 3             Phoenix Suns  116.0  Box Score        NaN  17071.0
# 4       Philadelphia 76ers  111.0  Box Score        NaN  19855.0
# ..                     ...    ...        ...        ...      ...
# 217         Denver Nuggets    NaN        NaN        NaN      NaN
# 218           Phoenix Suns    NaN        NaN        NaN      NaN
# 219              Utah Jazz    NaN        NaN        NaN      NaN
# 220       Sacramento Kings    NaN        NaN        NaN      NaN
# 221     Los Angeles Lakers    NaN        NaN        NaN      NaN
#
#                   Arena  Notes
# 0       Barclays Center    NaN
# 1             FTX Arena    NaN
# 2         Paycom Center    NaN
# 3      Footprint Center    NaN
# 4    Wells Fargo Center    NaN
# ..                  ...    ...
# 217          Ball Arena    NaN
# 218    Footprint Center    NaN
# 219        Vivint Arena    NaN
# 220     Golden 1 Center    NaN
# 221    Crypto.com Arena    NaN
#
# [222 rows x 11 columns]

# %%
def get_month(date):
    months = {
        'jan': 1,
        'feb': 2,
        'mar': 3,
        'apr':4,
         'may':5,
         'jun':6,
         'jul':7,
         'aug':8,
         'sep':9,
         'oct':10,
         'nov':11,
         'dec':12
        }
    return months[date[4:7].lower()]

# %%
def get_day(date):
    return date[8]

# %%
#reg22['TEAM_NAME'][0]
# Out:
# 'Philadelphia 76ers'

# %%
def month_clean(month,reg):
    month['month'] = month.apply(lambda row : get_month(row['Date']), axis = 1)
    month['day'] = month.apply(lambda row : get_day(row['Date']), axis = 1)
    month['home'] = month.apply(lambda row : get_team_id(row['Home/Neutral'],reg), axis = 1)
    month['away'] = month.apply(lambda row : get_team_id(row['Visitor/Neutral'],reg), axis = 1)
    return month[['home','away','month','day']]

# %%
#month_clean(november,reg22)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [42], line 1
# ----> 1 month_clean(november,reg22)
#
# NameError: name 'reg22' is not defined

# %%
#def get_todays_bets(month_cleaned, model,)

# %%
def get_team_id(team_name, reg):
    for i in team_ids:
        temp = reg[reg['TEAM_ID'] == i]
        if((temp['TEAM_NAME'].iloc[0]) == team_name):
            return i

# %%
def get_matchup_features(home_id, away_id, features):
    frame1 = pd.DataFrame()
    frame2 = pd.DataFrame()
    for i in features:
        if(i.TEAM_ID_A == home_id):
            stats1 = i
        if(i.TEAM_ID_A == away_id):
            stats2 = i
    frame1 = frame1.append(stats1)
    frame2 = frame2.append(stats2)
    frame1 = get_A_features(frame1)
    frame2 = get_A_features(frame2)
    frame1 = frame1.reset_index(drop=True)
    frame2 = frame2.reset_index(drop=True)
    merged = frame1.join(frame2,lsuffix='1',rsuffix='2')
    return feature_clean(merged)
    #return feature_clean(merged)

# %%
def get_current_features(features):
    feat = []
    for i in team_ids:
        temp = features[features['TEAM_ID_A'] == i]
        feat.append(temp.iloc[-1,:])
    return feat

# %%
def combine_features_current(reg,misc,adv,four):
    reg2 = reg_impute(reg_clean(reg),get_minutes(misc))
    adv2 = adv_impute(adv_clean(adv))
    four2 = four_impute(four_clean(four))
    merged = current_merger(reg2,adv2,four2)
    #merged = feature_clean(merged)
    merged = remove_unnamed(merged)
    return merged

# %%
def get_features(reg,misc,adv,four):
    reg2 = reg_impute(reg_clean(reg),get_minutes(misc))
    adv2 = adv_impute(adv_clean(adv))
    four2 = four_impute(four_clean(four))
    merged = merger(reg2,adv2,four2)
    #merged = feature_clean(merged)
    merged = remove_unnamed(merged)
    return merged

# %%
reg22 = pd.read_csv('reg2022.csv')
misc22 = pd.read_csv('misc2022.csv')
adv22 = pd.read_csv('adv2022.csv')
four22 = pd.read_csv('four2022.csv')

# %%
# Out:
# Empty DataFrame
# Columns: [TEAM_ID_A, FG_PCT_median_A, FG3_PCT_median_A, FT_PCT_median_A, GAME_ID, PTS_per_minute_A, FGM_per_minute_A, FGA_per_minute_A, FG3M_per_minute_A, FG3A_per_minute_A, FTM_per_minute_A, FTA_per_minute_A, OREB_per_minute_A, DREB_per_minute_A, REB_per_minute_A, AST_per_minute_A, STL_per_minute_A, BLK_per_minute_A, TOV_per_minute_A, PF_per_minute_A, PLUS_MINUS_per_minute_A, home_A, TEAM_ID_B_x, FG_PCT_median_B, FG3_PCT_median_B, FT_PCT_median_B, PTS_per_minute_B, FGM_per_minute_B, FGA_per_minute_B, FG3M_per_minute_B, FG3A_per_minute_B, FTM_per_minute_B, FTA_per_minute_B, OREB_per_minute_B, DREB_per_minute_B, REB_per_minute_B, AST_per_minute_B, STL_per_minute_B, BLK_per_minute_B, TOV_per_minute_B, PF_per_minute_B, PLUS_MINUS_per_minute_B, home_B, E_OFF_RATING_median_A, OFF_RATING_median_A, E_DEF_RATING_median_A, DEF_RATING_median_A, E_NET_RATING_median_A, NET_RATING_median_A, AST_PCT_median_A, AST_TOV_median_A, AST_RATIO_median_A, OREB_PCT_median_A, DREB_PCT_median_A, REB_PCT_median_A, E_TM_TOV_PCT_median_A, TM_TOV_PCT_median_A, EFG_PCT_median_A, TS_PCT_median_A, USG_PCT_median_A, E_USG_PCT_median_A, E_PACE_median_A, PACE_median_A, PACE_PER40_median_A, POSS_median_A, PIE_median_A, TEAM_ID_B_y, E_OFF_RATING_median_B, OFF_RATING_median_B, E_DEF_RATING_median_B, DEF_RATING_median_B, E_NET_RATING_median_B, NET_RATING_median_B, AST_PCT_median_B, AST_TOV_median_B, AST_RATIO_median_B, OREB_PCT_median_B, DREB_PCT_median_B, REB_PCT_median_B, E_TM_TOV_PCT_median_B, TM_TOV_PCT_median_B, EFG_PCT_median_B, TS_PCT_median_B, USG_PCT_median_B, E_USG_PCT_median_B, E_PACE_median_B, PACE_median_B, PACE_PER40_median_B, POSS_median_B, PIE_median_B, FTA_RATE_median_A, OPP_EFG_PCT_median_A, OPP_FTA_RATE_median_A, OPP_TOV_PCT_median_A, OPP_OREB_PCT_median_A, TEAM_ID_B, FTA_RATE_median_B, OPP_EFG_PCT_median_B, OPP_FTA_RATE_median_B, OPP_TOV_PCT_median_B, ...]
# Index: []
#
# [0 rows x 101 columns]

# %%
#feat22[feat22['TEAM_ID_A'] == 1610612747]
# Out:
#       TEAM_ID_A  FG_PCT_median_A  FG3_PCT_median_A  FT_PCT_median_A   GAME_ID  \
# 2    1610612747              NaN               NaN              NaN  22200002
# 31   1610612747           0.4260            0.2500            0.760  22200016
# 72   1610612747           0.3885            0.2250            0.803  22200037
# 127  1610612747           0.4260            0.2000            0.800  22200064
# 150  1610612747           0.4350            0.2250            0.780  22200076
# 189  1610612747           0.4260            0.2500            0.760  22200095
# 233  1610612747           0.4350            0.2585            0.780  22200117
#
#      PTS_per_minute_A  FGM_per_minute_A  FGA_per_minute_A  FG3M_per_minute_A  \
# 2                 NaN               NaN               NaN                NaN
# 31           2.270833          0.833333          1.958333           0.208333
# 72           2.145833          0.760417          1.958333           0.197917
# 127          2.152778          0.791667          1.944444           0.173611
# 150          2.130208          0.802083          1.927083           0.171875
# 189          2.129167          0.795833          1.912500           0.175000
# 233          2.194444          0.822917          1.927083           0.190972
#
#      FG3A_per_minute_A  ...  OPP_EFG_PCT_median_A  OPP_FTA_RATE_median_A  \
# 2                  NaN  ...                   NaN                    NaN
# 31            0.833333  ...                 0.535                 0.2320
# 72            0.885417  ...                 0.527                 0.3100
# 127           0.819444  ...                 0.519                 0.3210
# 150           0.770833  ...                 0.512                 0.2765
# 189           0.737500  ...                 0.505                 0.2420
# 233           0.718750  ...                 0.505                 0.2370
#
#      OPP_TOV_PCT_median_A  OPP_OREB_PCT_median_A   TEAM_ID_B  \
# 2                     NaN                    NaN  1610612744
# 31                 0.1550                  0.281  1610612746
# 72                 0.1855                  0.282  1610612757
# 127                0.1860                  0.283  1610612743
# 150                0.1705                  0.282  1610612750
# 189                0.1550                  0.281  1610612743
# 233                0.1310                  0.281  1610612740
#
#      FTA_RATE_median_B  OPP_EFG_PCT_median_B  OPP_FTA_RATE_median_B  \
# 2                  NaN                   NaN                    NaN
# 31                 NaN                   NaN                    NaN
# 72              0.4070                0.5350                 0.2235
# 127             0.2540                0.5825                 0.3400
# 150             0.2500                0.5140                 0.2220
# 189             0.2595                0.5450                 0.2760
# 233             0.2410                0.5135                 0.2435
#
#      OPP_TOV_PCT_median_B  OPP_OREB_PCT_median_B
# 2                     NaN                    NaN
# 31                    NaN                    NaN
# 72                 0.1525                 0.2585
# 127                0.1455                 0.2835
# 150                0.1180                 0.3210
# 189                0.1280                 0.2715
# 233                0.1410                 0.2870
#
# [7 rows x 101 columns]

# %%
# Out:
#       FG_PCT_median_A  FG3_PCT_median_A  FT_PCT_median_A  PTS_per_minute_A  \
# 804             0.446            0.3440           0.8060          2.315149
# 805             0.452            0.3205           0.7890          2.210481
# 806             0.484            0.3440           0.8080          2.350021
# 807             0.472            0.3660           0.7500          2.259693
# 808             0.446            0.3495           0.7965          2.116609
# ...               ...               ...              ...               ...
# 1849            0.466            0.3530           0.7780          2.279330
# 1850            0.471            0.3790           0.7930          2.373405
# 1851            0.471            0.3510           0.7370          2.297352
# 1852            0.466            0.3550           0.8260          2.368004
# 1853            0.457            0.3680           0.7310          2.353301
#
#       FGM_per_minute_A  FGA_per_minute_A  FG3M_per_minute_A  \
# 804           0.845356          1.883228           0.206943
# 805           0.832828          1.818103           0.205284
# 806           0.875053          1.848128           0.235170
# 807           0.871506          1.812894           0.194770
# 808           0.792169          1.789587           0.188468
# ...                ...               ...                ...
# 1849          0.863382          1.852971           0.226765
# 1850          0.849923          1.805003           0.206483
# 1851          0.831721          1.775967           0.249236
# 1852          0.873243          1.874776           0.227447
# 1853          0.889880          1.922253           0.231710
#
#       FG3A_per_minute_A  FTM_per_minute_A  FTA_per_minute_A  ...  \
# 804            0.588819          0.417493          0.526601  ...
# 805            0.608922          0.339541          0.436120  ...
# 806            0.682373          0.364745          0.457299  ...
# 807            0.520289          0.321912          0.430117  ...
# 808            0.534854          0.343804          0.432874  ...
# ...                 ...               ...               ...  ...
# 1849           0.644490          0.325800          0.430929  ...
# 1850           0.533435          0.467075          0.589587  ...
# 1851           0.701120          0.384674          0.524185  ...
# 1852           0.637874          0.394071          0.483516  ...
# 1853           0.614836          0.341830          0.471323  ...
#
#       E_PACE_median_B  PACE_median_B  PACE_PER40_median_B  POSS_median_B  \
# 804            101.50         100.00                83.33          101.5
# 805            102.48         100.50                83.75          101.0
# 806            100.89          98.75                82.29          100.0
# 807            102.10         100.50                83.75          101.0
# 808            102.06          99.50                82.92          100.0
# ...               ...            ...                  ...            ...
# 1849           102.50         100.50                83.75          101.0
# 1850           102.08         100.00                83.33          100.0
# 1851           104.12         102.34                85.28          103.0
# 1852           105.28         103.50                86.25          103.0
# 1853           101.82         100.00                83.33          100.0
#
#       PIE_median_B  FTA_RATE_median_B  OPP_EFG_PCT_median_B  \
# 804         0.4440             0.2290                0.5440
# 805         0.4975             0.2805                0.5275
# 806         0.5585             0.2240                0.5060
# 807         0.5480             0.2290                0.4950
# 808         0.5230             0.2170                0.5000
# ...            ...                ...                   ...
# 1849        0.4930             0.2530                0.5350
# 1850        0.5480             0.2940                0.5000
# 1851        0.5120             0.3260                0.5160
# 1852        0.4870             0.2420                0.5350
# 1853        0.5350             0.2560                0.5120
#
#       OPP_FTA_RATE_median_B  OPP_TOV_PCT_median_B  OPP_OREB_PCT_median_B
# 804                  0.3155                0.1510                 0.3060
# 805                  0.2470                0.1520                 0.2965
# 806                  0.2290                0.1675                 0.2680
# 807                  0.2250                0.1480                 0.2980
# 808                  0.2780                0.1520                 0.2670
# ...                     ...                   ...                    ...
# 1849                 0.2470                0.1400                 0.2900
# 1850                 0.2420                0.1330                 0.2320
# 1851                 0.2890                0.1230                 0.2750
# 1852                 0.2690                0.1520                 0.2830
# 1853                 0.2650                0.1210                 0.2550
#
# [1008 rows x 96 columns]

# %%
def odds_convert(american_lines):
    odds = []
    for i in american_lines:
        if(i < 0):
            odds.append((i -100)/i)
        else:
            odds.append((i+100)/100)
    return odds

# %%
def get_targets_OU(features, targets):
    df = pd.DataFrame()
    for i in range(len(features)):
        year = features[i]
        vegas = targets[i]
        vegas = vegas[['Pinnacle_Line_OU','Pinnacle_Odds_OU','Total','GameId']]
        merged = pd.merge(year,vegas, left_on = 'GAME_ID',right_on = 'GameId')
        merged = merged.drop_duplicates(subset = ['GAME_ID','TEAM_ID_A'])
        merged = merged.dropna()
        df = df.append(merged)
    y = df[['Pinnacle_Line_OU','Total']]
    #odds = y['Pinnacle_Odds_OU']
    #new = odds_convert(odds)
    #y['Pinnacle_Odds_OU'] = new
    x = df.drop(columns = ['Pinnacle_Line_OU','Pinnacle_Odds_OU','Total','GameId'])
    x = feature_clean(x)
    return[x,y]

# %%
def get_targets_ML(features, targets):
    df = pd.DataFrame()
    for i in range(len(features)):
        year = features[i]
        vegas = targets[i]
        vegas = combine_vegas_games(vegas)
        vegas = vegas[['Pinnacle_ML_A','Pinnacle_ML_B','Result_A','GameId','TeamId_A']]
        merged = pd.merge(year,vegas, left_on = ['GAME_ID','TEAM_ID_A'],right_on = ['GameId','TeamId_A'])
        merged = merged.drop_duplicates(subset = ['GAME_ID','TEAM_ID_A'])
        merged = merged.dropna()
        df = df.append(merged)
    y = df[['Result_A','Pinnacle_ML_A','Pinnacle_ML_B','GameId']]
    y['Odds_A'] = odds_convert(y['Pinnacle_ML_A'])
    y['Odds_B'] = odds_convert(y['Pinnacle_ML_B'])
    y['y_true'] = y.apply(lambda row : get_y_true(row['Result_A'],
                     row['Odds_A'], row['Odds_B']), axis = 1)
    x = df.drop(columns = ['Pinnacle_ML_A','Pinnacle_ML_B','Result_A','GameId','TeamId_A'])
    x = feature_clean(x)
    y = y[['y_true']]
    y2 = pd.DataFrame(y['y_true'].to_list(), columns = ['a_win', 'b_win', 'no_bet','odds_a','odds_b'])
    return[x,y2]

# %%
def get_y_true(result_a, ml_a,ml_b):
    if(result_a == 'W'):
        return [1,0,0,ml_a,ml_b]
    else:
        return [0,1,0,ml_a,ml_b]

# %%
def OU_accuracy(X_test, model, y_test,thresh):
    y_test['predictions'] = model.predict(X_test)
    y_test['diff'] = abs(y_test['Pinnacle_Line_OU'] - y_test['predictions'])
    y_test = y_test[y_test['diff'] > thresh]
    counter = 0
    for i in range(y_test.shape[0]):
        ou = y_test.iloc[i,0]
        total = y_test.iloc[i,1]
        predictions = y_test.iloc[i,2]
        if(ou > total):
            if(predictions < ou):
                counter = counter + 1
        if(ou < total):
            if(predictions > ou):
                counter = counter + 1
    return(counter/y_test.shape[0])

# %%
def decorrelation_loss(y_true, y_pred):
    p = y_true[:,0:1]
    result = y_true[:,1:2]
    return K.sqrt(K.mean(K.square(result - y_pred) - (0.6 * K.square(p - y_pred))))

# %%
def profit_loss(y_true,y_pred):
    home_win = y_true[:,0:1]
    away_win = y_true[:,1:2]
    no_bet = y_true[:,2:3]
    odds_a = y_true[:,3:4]
    odds_b = y_true[:,4:5]
    gain_loss_vector = K.concatenate([(home_win * (odds_a - 1)) + ((1-home_win)* -1),
                                     (away_win * (odds_b - 1)) + ((1-away_win) * -1),
                                     K.zeros_like(odds_a)],axis=1)
    return( -1 * (K.mean(K.sum(gain_loss_vector * y_pred, axis=1))))

# %%
# Out:
#       a_win  b_win  no_bet    odds_a    odds_b
# 0         1      0       0  1.294118  3.970000
# 1         0      1       0  3.970000  1.294118
# 2         1      0       0  1.699301  2.290000
# 3         0      1       0  2.290000  1.699301
# 4         1      0       0  1.564972  2.590000
# ...     ...    ...     ...       ...       ...
# 4495      0      1       0  2.930000  1.462963
# 4496      1      0       0  1.291545  4.000000
# 4497      0      1       0  4.000000  1.291545
# 4498      0      1       0  2.480000  1.609756
# 4499      1      0       0  1.609756  2.480000
#
# [4500 rows x 5 columns]

# %%
#X_train[['FG_PCT_median_A','FG_PCT_median_B']]
# Out:
#      FG_PCT_median_A  FG_PCT_median_B
# 0             0.4550           0.4410
# 1             0.4410           0.4550
# 2             0.4540           0.4635
# 3             0.4635           0.4540
# 4             0.4690           0.4720
# ..               ...              ...
# 799           0.4860           0.4690
# 800           0.4540           0.4570
# 801           0.4570           0.4540
# 802           0.4710           0.4370
# 803           0.4370           0.4710
#
# [4500 rows x 2 columns]

# %%
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
def OU_features(features,corr,thresh):
    size = corr.shape[0]-1
    features2 = features.copy(deep=False)
    for columnName in corr:
        if (corr[columnName][size] < thresh):
            features2 = features2.drop(columns = [columnName])
    return features2

# %%
def get_bets(pred_odds):
    pred_odds['prob_a'] = 1 / (pred_odds['odds_a'])
    pred_odds['bets'] = pred_odds.apply(lambda row : get_bet(row['predictions'],row['prob_a']), axis = 1)
    return pred_odds

# %%
def get_bet(pred,odds):
    if((pred-odds) > 0):
        return(pred-odds)
    else:
        return 0

# %%
def get_profits(preds):
    preds['profit'] = preds.apply(lambda row: get_profit(row['odds_a'],row['bets'],row['a_win']),axis=1)
    return(preds['profit'].sum())

# %%
def filter_features(features, features_list):
    features2 = features.copy(deep=False)
    for columnName in features2:
        if(columnName in features_list):
            continue
        else:
            features2 = features2.drop(columns = [columnName])
    return features2

# %%
def get_profit(odds,bet,result):
    if(result == 1):
        return((bet*odds) - bet)
    if(result == 0):
        return(-1 * bet)

# %%
def profit(model, X_test, y_test):
    pred = model.predict(X_test)
    odds = y_test['odds_a']
    result =  y_test['a_win']
    test = pd.DataFrame()
    test['odds_a'] = odds
    test['a_win'] = result
    test['predictions'] = pred
    get_bets(test)
    profit = get_profits(test)
    print('total profit:  ' + str(profit))
    print('total bet:  ' + str(test['bets'].sum()))
    print('percent_return:  ' + str((100 * (profit/test['bets'].sum()))))

# %%
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
def get_current_reg(start_date):
    current_reg = pull_reg_season('2022',start_date,str(date.today()))
    return current_reg

# %%
from datetime import date
def get_current_data(current_reg):
    four = pull_stats(boxscorefourfactorsv2.BoxScoreFourFactorsV2,1,get_ids(current_reg))
    adv = pull_stats(boxscoreadvancedv2.BoxScoreAdvancedV2,1,get_ids(current_reg))
    misc = pull_stats(boxscoremiscv2.BoxScoreMiscV2,1,get_ids(current_reg))
    totalcurrent = get_features(current_reg,misc,adv,four)
    return totalcurrent

# %%
#profit = 0
#bets = []
#betting_total = 0
#bets_placed = 0
#predictions = model.predict(X_test)
    #for i in range(len(predictions)):
     #   predictions[i] = np.append(predictions[i],[odds.iloc[i,3]])
      #  predictions[i]= np.append(predictions[i],[odds.iloc[i,4]])
    #bets = []
#for i in range(len(predictions)):
#    if((predictions[i][0] > prediction_threshold) & (odds.iloc[i,3] > odds_threshold)):
 #  #     bets = np.append(bets,betting_function(predictions[i][0],odds.iloc[i,3]))
  #      bets_placed += 1

# %%
#model.predict(X_train)
# Out:
# 141/141 [==============================] - 0s 1ms/step
# array([[0.0846156 , 0.6271469 , 0.28823745],
#        [0.02357252, 0.8917778 , 0.08464961],
#        [0.05861508, 0.75777674, 0.18360822],
#        ...,
#        [0.10084126, 0.557557  , 0.3416018 ],
#        [0.05140304, 0.50296307, 0.44563386],
#        [0.06415238, 0.41163275, 0.5242149 ]], dtype=float32)

# %%
def profit_betting(odds_threshold, prediction_threshold, predictions,odds,betting_function):
    profit = 0
    bets = []
    betting_total = 0
    bets_placed = 0
    #for i in range(len(predictions)):
     #   predictions[i] = np.append(predictions[i],[odds.iloc[i,3]])
      #  predictions[i]= np.append(predictions[i],[odds.iloc[i,4]])
    #bets = []
    for i in range(len(predictions)):
        if((predictions[i][0] > prediction_threshold) & (odds.iloc[i,3] > odds_threshold)):
            bets = np.append(bets,betting_function(predictions[i][0],odds.iloc[i,3]))
            bets_placed += 1
        else:
            bets = np.append(bets,0)
    for i in range(len(bets)):
        if(bets[i] > 0):
            if(odds.iloc[i,0] == 1):
                profit = profit + ((bets[i] * odds.iloc[i,3])- bets[i])
            else:
                profit = profit - bets[i]
    for i in bets:
        betting_total = betting_total + i
        
        
    print('Odds Threshold: ' + str(odds_threshold))
    print('Pred Threshold: ' + str(prediction_threshold))
    print('Number of Bets Placed: ' + str(bets_placed))
    print('Total Bet: ' + str(betting_total))
    print('Profit: ' + str(profit))
    print('Percent Return: ' + str(profit/betting_total))
    return ((profit/betting_total) * (10*bets_placed))

# %%
def betting_function(pred_a,odds_a):
    return (pred_a)

# %%
def tune_betting_parameters(odds_threshold_range,odds_threshold_increment, prediction_threshold_range,prediction_threshold_increment,betting_function,X_test,y_test,model):
    odds_min = odds_threshold_range[0]
    odds_max = odds_threshold_range[1]
    pred_min = prediction_threshold_range[0]
    pred_max = prediction_threshold_range[1]
    max_return = -100
    max_odds_thresh = 0
    max_pred_thresh = 0
    for x in np.arange(odds_min, odds_max, odds_threshold_increment):
        for y in np.arange(pred_min, pred_max, prediction_threshold_increment):
            if(profit_betting(x,y,model.predict(X_test),y_test,betting_function) > max_return):
                max_return = profit_betting(x,y,model.predict(X_test),y_test,betting_function)
                max_odds_thresh = x
                max_pred_thresh = y
    print('best odds thresh: ' + str(max_odds_thresh))
    print('best pred thresh: ' + str(max_pred_thresh))
    print('max_return: '+ str(max_return))

# %%
# Out:
#       FG_PCT_median_A  FG3_PCT_median_A  FT_PCT_median_A  PTS_per_minute_A  \
# 804             0.446            0.3440           0.8060          2.315149
# 805             0.452            0.3205           0.7890          2.210481
# 806             0.484            0.3440           0.8080          2.350021
# 807             0.472            0.3660           0.7500          2.259693
# 808             0.446            0.3495           0.7965          2.116609
# ...               ...               ...              ...               ...
# 1849            0.466            0.3530           0.7780          2.279330
# 1850            0.471            0.3790           0.7930          2.373405
# 1851            0.471            0.3510           0.7370          2.297352
# 1852            0.466            0.3550           0.8260          2.368004
# 1853            0.457            0.3680           0.7310          2.353301
#
#       FGM_per_minute_A  FGA_per_minute_A  FG3M_per_minute_A  \
# 804           0.845356          1.883228           0.206943
# 805           0.832828          1.818103           0.205284
# 806           0.875053          1.848128           0.235170
# 807           0.871506          1.812894           0.194770
# 808           0.792169          1.789587           0.188468
# ...                ...               ...                ...
# 1849          0.863382          1.852971           0.226765
# 1850          0.849923          1.805003           0.206483
# 1851          0.831721          1.775967           0.249236
# 1852          0.873243          1.874776           0.227447
# 1853          0.889880          1.922253           0.231710
#
#       FG3A_per_minute_A  FTM_per_minute_A  FTA_per_minute_A  ...  \
# 804            0.588819          0.417493          0.526601  ...
# 805            0.608922          0.339541          0.436120  ...
# 806            0.682373          0.364745          0.457299  ...
# 807            0.520289          0.321912          0.430117  ...
# 808            0.534854          0.343804          0.432874  ...
# ...                 ...               ...               ...  ...
# 1849           0.644490          0.325800          0.430929  ...
# 1850           0.533435          0.467075          0.589587  ...
# 1851           0.701120          0.384674          0.524185  ...
# 1852           0.637874          0.394071          0.483516  ...
# 1853           0.614836          0.341830          0.471323  ...
#
#       E_PACE_median_B  PACE_median_B  PACE_PER40_median_B  POSS_median_B  \
# 804            101.50         100.00                83.33          101.5
# 805            102.48         100.50                83.75          101.0
# 806            100.89          98.75                82.29          100.0
# 807            102.10         100.50                83.75          101.0
# 808            102.06          99.50                82.92          100.0
# ...               ...            ...                  ...            ...
# 1849           102.50         100.50                83.75          101.0
# 1850           102.08         100.00                83.33          100.0
# 1851           104.12         102.34                85.28          103.0
# 1852           105.28         103.50                86.25          103.0
# 1853           101.82         100.00                83.33          100.0
#
#       PIE_median_B  FTA_RATE_median_B  OPP_EFG_PCT_median_B  \
# 804         0.4440             0.2290                0.5440
# 805         0.4975             0.2805                0.5275
# 806         0.5585             0.2240                0.5060
# 807         0.5480             0.2290                0.4950
# 808         0.5230             0.2170                0.5000
# ...            ...                ...                   ...
# 1849        0.4930             0.2530                0.5350
# 1850        0.5480             0.2940                0.5000
# 1851        0.5120             0.3260                0.5160
# 1852        0.4870             0.2420                0.5350
# 1853        0.5350             0.2560                0.5120
#
#       OPP_FTA_RATE_median_B  OPP_TOV_PCT_median_B  OPP_OREB_PCT_median_B
# 804                  0.3155                0.1510                 0.3060
# 805                  0.2470                0.1520                 0.2965
# 806                  0.2290                0.1675                 0.2680
# 807                  0.2250                0.1480                 0.2980
# 808                  0.2780                0.1520                 0.2670
# ...                     ...                   ...                    ...
# 1849                 0.2470                0.1400                 0.2900
# 1850                 0.2420                0.1330                 0.2320
# 1851                 0.2890                0.1230                 0.2750
# 1852                 0.2690                0.1520                 0.2830
# 1853                 0.2650                0.1210                 0.2550
#
# [1008 rows x 96 columns]

# %%
#tune_betting_parameters([0,3],0.1,[0.1,0.45],0.05,betting_function,X_test,y_test2,model)
# Out:
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.0
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.0
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.0
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0.0
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.0
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.0
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.0
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.0
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.1
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.1
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.1
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.1
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.1
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 4ms/step
# Odds Threshold: 0.1
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.1
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.2
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0.2
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0.2
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0.2
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.2
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.2
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.2
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.30000000000000004
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.30000000000000004
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.30000000000000004
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.30000000000000004
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.30000000000000004
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.30000000000000004
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.30000000000000004
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.4
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.4
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.4
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.4
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.4
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.4
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.4
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.5
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0.5
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.5
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.5
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0.5
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.5
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.5
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.6000000000000001
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.6000000000000001
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.6000000000000001
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.6000000000000001
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.6000000000000001
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.6000000000000001
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.6000000000000001
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.7000000000000001
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.7000000000000001
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.7000000000000001
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.7000000000000001
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.7000000000000001
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.7000000000000001
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.7000000000000001
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.8
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.8
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.8
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0.8
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.8
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.8
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 4ms/step
# Odds Threshold: 0.8
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.9
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.9
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.9
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.9
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 4ms/step
# Odds Threshold: 0.9
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0.9
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 0.9
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.0
# Pred Threshold: 0.1
# Number of Bets Placed: 390
# Total Bet: 147.40872795134783
# Profit: -5.811542481073463
# Percent Return: -0.03942468374729859
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.0
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 313
# Total Bet: 137.96753887832165
# Profit: -7.025360191147868
# Percent Return: -0.05092038495623073
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.0
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 259
# Total Bet: 128.79917180538177
# Profit: -5.169030237589769
# Percent Return: -0.040132480396692934
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.0
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 222
# Total Bet: 120.39526098966599
# Profit: -4.119609375128482
# Percent Return: -0.03421737152496463
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.0
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 190
# Total Bet: 111.64437499642372
# Profit: -11.761652422943442
# Percent Return: -0.10534926119941287
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.0
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 168
# Total Bet: 104.55219650268555
# Profit: -10.434262724141405
# Percent Return: -0.09979955537207091
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.0
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 144
# Total Bet: 95.58711072802544
# Profit: -10.706789785587056
# Percent Return: -0.11201081091415292
# 32/32 [==============================] - 0s 6ms/step
# Odds Threshold: 1.1
# Pred Threshold: 0.1
# Number of Bets Placed: 379
# Total Bet: 144.3924622386694
# Profit: -5.156890719305288
# Percent Return: -0.035714403919377406
# 32/32 [==============================] - 0s 6ms/step
# Odds Threshold: 1.1
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 308
# Total Bet: 135.62446396052837
# Profit: -6.4389515136566935
# Percent Return: -0.04747632783662586
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.1
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 254
# Total Bet: 126.4560968875885
# Profit: -4.582621560098593
# Percent Return: -0.036238834448387686
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.1
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 218
# Total Bet: 118.28143772482872
# Profit: -3.5281644135213996
# Percent Return: -0.02982855536241757
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.1
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 218
# Total Bet: 118.28143772482872
# Profit: -3.5281644135213996
# Percent Return: -0.02982855536241757
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.1
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 186
# Total Bet: 109.53055173158646
# Profit: -11.17020746133636
# Percent Return: -0.10198257275933262
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.1
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 165
# Total Bet: 102.77298527956009
# Profit: -9.833923237236295
# Percent Return: -0.09568587708614616
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.1
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 141
# Total Bet: 93.80789950489998
# Profit: -10.106450298681946
# Percent Return: -0.1077355995819312
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.2000000000000002
# Pred Threshold: 0.1
# Number of Bets Placed: 350
# Total Bet: 134.16642314195633
# Profit: -4.237430046904605
# Percent Return: -0.031583386868867656
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.2000000000000002
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 285
# Total Bet: 126.1484352350235
# Profit: -5.406032183276915
# Percent Return: -0.04285453222788767
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.2000000000000002
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 236
# Total Bet: 117.83313709497452
# Profit: -3.6032620275440577
# Percent Return: -0.030579360919838684
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.2000000000000002
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 204
# Total Bet: 110.55968526005745
# Profit: -2.416808912703967
# Percent Return: -0.021859766577836868
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.2000000000000002
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 204
# Total Bet: 110.55968526005745
# Profit: -2.416808912703967
# Percent Return: -0.021859766577836868
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.2000000000000002
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 174
# Total Bet: 102.32702699303627
# Profit: -9.996895623845603
# Percent Return: -0.09769555431846885
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.2000000000000002
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 155
# Total Bet: 96.24361377954483
# Profit: -8.957813827763303
# Percent Return: -0.09307437112951754
# 32/32 [==============================] - 0s 5ms/step
# Odds Threshold: 1.2000000000000002
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 133
# Total Bet: 88.0370843410492
# Profit: -9.55752489929938
# Percent Return: -0.10856248785198555
# 32/32 [==============================] - 0s 7ms/step
# Odds Threshold: 1.3
# Pred Threshold: 0.1
# Number of Bets Placed: 328
# Total Bet: 126.70021843165159
# Profit: -5.791507150696296
# Percent Return: -0.04571031701749215
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.3
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 268
# Total Bet: 119.28891083598137
# Profit: -6.80337016682725
# Percent Return: -0.05703271258953548
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.3
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 221
# Total Bet: 111.30841824412346
# Profit: -4.915276973786781
# Percent Return: -0.044159076656776444
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.3
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 190
# Total Bet: 104.24950298666954
# Profit: -3.9433604364098445
# Percent Return: -0.03782617972686244
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.3
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 165
# Total Bet: 97.39120727777481
# Profit: -11.168310943450923
# Percent Return: -0.11467473559083388
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.3
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 148
# Total Bet: 91.94532468914986
# Profit: -9.96682590260112
# Percent Return: -0.10839948563232676
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.3
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 126
# Total Bet: 83.73879525065422
# Profit: -10.566536974137197
# Percent Return: -0.12618448763811949
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.4000000000000001
# Pred Threshold: 0.1
# Number of Bets Placed: 307
# Total Bet: 119.8017657995224
# Profit: -6.189744727253656
# Percent Return: -0.05166655671512925
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.4000000000000001
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 253
# Total Bet: 113.09605415165424
# Profit: -7.2450001988088495
# Percent Return: -0.06406059215022471
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.4000000000000001
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 209
# Total Bet: 105.61756379902363
# Profit: -5.166973586810032
# Percent Return: -0.04892153729887299
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.4000000000000001
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 181
# Total Bet: 99.21709218621254
# Profit: -4.279595535072329
# Percent Return: -0.043133652083254995
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.4000000000000001
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 157
# Total Bet: 92.62663194537163
# Profit: -11.422135128866081
# Percent Return: -0.12331372618193123
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.4000000000000001
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 141
# Total Bet: 87.50106012821198
# Profit: -10.11665308429377
# Percent Return: -0.11561749159919003
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.4000000000000001
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 119
# Total Bet: 79.29453068971634
# Profit: -10.716364155829845
# Percent Return: -0.13514632172757968
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.5
# Pred Threshold: 0.1
# Number of Bets Placed: 289
# Total Bet: 112.3775205090642
# Profit: -7.8194909223486
# Percent Return: -0.06958234072905971
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.5
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 237
# Total Bet: 105.90813562273979
# Profit: -8.76842439980295
# Percent Return: -0.08279273682087422
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.5
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 196
# Total Bet: 98.94668819010258
# Profit: -6.74310853322451
# Percent Return: -0.06814890580540935
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.5
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 169
# Total Bet: 92.7674902677536
# Profit: -5.7461890505649675
# Percent Return: -0.06194184012071273
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.5
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 147
# Total Bet: 86.7568145096302
# Profit: -12.624979006289005
# Percent Return: -0.14552146799820093
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.5
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 132
# Total Bet: 81.96493077278137
# Profit: -11.653185042027516
# Percent Return: -0.14217281625396389
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.5
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 110
# Total Bet: 73.75840133428574
# Profit: -12.252896113563597
# Percent Return: -0.16612204022740906
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.6
# Pred Threshold: 0.1
# Number of Bets Placed: 268
# Total Bet: 103.76601117104292
# Profit: -7.932647595603647
# Percent Return: -0.07644745621500137
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.6
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 216
# Total Bet: 97.29662628471851
# Profit: -8.88158107305799
# Percent Return: -0.09128354612284166
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.6
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 178
# Total Bet: 90.86472085118294
# Profit: -7.137855386841525
# Percent Return: -0.07855474952189434
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.6
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 153
# Total Bet: 85.13309928774834
# Profit: -6.588512263096358
# Percent Return: -0.07739072485576151
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.6
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 133
# Total Bet: 79.66442030668259
# Profit: -13.172842744418485
# Percent Return: -0.16535415300465686
# 32/32 [==============================] - 0s 5ms/step
# Odds Threshold: 1.6
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 122
# Total Bet: 76.1766599714756
# Profit: -11.962683282026155
# Percent Return: -0.15703869513976576
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.6
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 103
# Total Bet: 69.07678359746933
# Profit: -12.503045270129455
# Percent Return: -0.18100213442172358
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.7000000000000002
# Pred Threshold: 0.1
# Number of Bets Placed: 249
# Total Bet: 97.03702555596828
# Profit: -6.138646705393746
# Percent Return: -0.06326087047931146
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.7000000000000002
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 199
# Total Bet: 90.80354315042496
# Profit: -7.126405051304711
# Percent Return: -0.07848157466167507
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.7000000000000002
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 164
# Total Bet: 84.88546438515186
# Profit: -5.577032322087123
# Percent Return: -0.0657006751683938
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.7000000000000002
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 141
# Total Bet: 79.63002640008926
# Profit: -5.11067096971628
# Percent Return: -0.06418019936397448
# 32/32 [==============================] - 0s 4ms/step
# Odds Threshold: 1.7000000000000002
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 124
# Total Bet: 74.97550618648529
# Profit: -11.179138854600968
# Percent Return: -0.1491038796963276
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.7000000000000002
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 115
# Total Bet: 72.106799274683
# Profit: -10.588032815613332
# Percent Return: -0.14683820280635912
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.7000000000000002
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 96
# Total Bet: 65.00692290067673
# Profit: -11.128394803716631
# Percent Return: -0.17118784134298384
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.8
# Pred Threshold: 0.1
# Number of Bets Placed: 224
# Total Bet: 89.40779823064804
# Profit: -4.964770406116231
# Percent Return: -0.055529500830659766
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.8
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 180
# Total Bet: 83.93874807655811
# Profit: -5.362638832219413
# Percent Return: -0.06388752459505716
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.8
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 150
# Total Bet: 78.89514487981796
# Profit: -4.340024468277149
# Percent Return: -0.05501003230158671
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.8
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 130
# Total Bet: 74.32904490828514
# Profit: -4.1351935390706736
# Percent Return: -0.055633615959590266
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.8
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 115
# Total Bet: 70.21167290210724
# Profit: -10.276877969537178
# Percent Return: -0.14636993458147246
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.8
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 106
# Total Bet: 67.34296599030495
# Profit: -9.685771930549542
# Percent Return: -0.1438275221192954
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.8
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 89
# Total Bet: 61.006551295518875
# Profit: -10.297529958818359
# Percent Return: -0.16879383836887604
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.9000000000000001
# Pred Threshold: 0.1
# Number of Bets Placed: 213
# Total Bet: 83.57190224528313
# Profit: -4.907509659063287
# Percent Return: -0.05872200497075883
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 1.9000000000000001
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 169
# Total Bet: 78.1028520911932
# Profit: -5.305378085166465
# Percent Return: -0.06792809664584187
# 32/32 [==============================] - 0s 5ms/step
# Odds Threshold: 1.9000000000000001
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 143
# Total Bet: 73.71712857484818
# Profit: -4.650891053021204
# Percent Return: -0.06309105011190112
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.9000000000000001
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 123
# Total Bet: 69.15102860331535
# Profit: -4.4460601238147275
# Percent Return: -0.0642949239312048
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.9000000000000001
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 108
# Total Bet: 65.03365659713745
# Profit: -10.587744554281235
# Percent Return: -0.16280407881520334
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.9000000000000001
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 100
# Total Bet: 62.50102314352989
# Profit: -9.716577300131322
# Percent Return: -0.15546269183174455
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 1.9000000000000001
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 84
# Total Bet: 56.529552668333054
# Profit: -10.693279547989368
# Percent Return: -0.18916264225065363
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.0
# Pred Threshold: 0.1
# Number of Bets Placed: 204
# Total Bet: 80.27978949248791
# Profit: -3.2263989127427344
# Percent Return: -0.040189429159435464
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.0
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 162
# Total Bet: 75.09939393401146
# Profit: -3.349920938760042
# Percent Return: -0.044606497646353306
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.0
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 138
# Total Bet: 71.075992166996
# Profit: -3.057755655944349
# Percent Return: -0.04302093523731649
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.0
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 119
# Total Bet: 66.75552898645401
# Profit: -2.6254832535982153
# Percent Return: -0.039329824712062075
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.0
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 105
# Total Bet: 62.93399101495743
# Profit: -8.488078972101214
# Percent Return: -0.134872726728611
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.0
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 97
# Total Bet: 60.40135756134987
# Profit: -7.616911717951299
# Percent Return: -0.1261049755415642
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.0
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 81
# Total Bet: 54.42988708615303
# Profit: -8.593613965809347
# Percent Return: -0.15788410422764892
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.1
# Number of Bets Placed: 192
# Total Bet: 75.26857792586088
# Profit: -1.8618830166757123
# Percent Return: -0.024736524430017216
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 154
# Total Bet: 70.53004013001919
# Profit: -1.9637084127962587
# Percent Return: -0.027842156465191913
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 154
# Total Bet: 70.53004013001919
# Profit: -1.9637084127962587
# Percent Return: -0.027842156465191913
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 132
# Total Bet: 66.87235450744629
# Profit: -2.037259274423123
# Percent Return: -0.03046489523852899
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 132
# Total Bet: 66.87235450744629
# Profit: -2.037259274423123
# Percent Return: -0.03046489523852899
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 113
# Total Bet: 62.5518913269043
# Profit: -1.6049868720769889
# Percent Return: -0.02565848670648693
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 113
# Total Bet: 62.5518913269043
# Profit: -1.6049868720769889
# Percent Return: -0.02565848670648693
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 99
# Total Bet: 58.730353355407715
# Profit: -7.467582590579986
# Percent Return: -0.12715030923430318
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 91
# Total Bet: 56.197719901800156
# Profit: -6.5964153364300735
# Percent Return: -0.11737870055861063
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.1
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 75
# Total Bet: 50.22624942660332
# Profit: -7.57311758428812
# Percent Return: -0.15078007358194
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.2
# Pred Threshold: 0.1
# Number of Bets Placed: 183
# Total Bet: 72.82272373884916
# Profit: -1.8102278313040727
# Percent Return: -0.0248580077531261
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.2
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 146
# Total Bet: 68.19614790380001
# Profit: -2.024015188217163
# Percent Return: -0.029679318413590065
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.2
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 126
# Total Bet: 64.84568935632706
# Profit: -2.085480023175479
# Percent Return: -0.032160657768872905
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.2
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 109
# Total Bet: 60.995507538318634
# Profit: -1.632290438413621
# Percent Return: -0.026760830498675375
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.2
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 95
# Total Bet: 57.17396956682205
# Profit: -7.494886156916617
# Percent Return: -0.13108913398355124
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.2
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 88
# Total Bet: 54.96124476194382
# Profit: -6.943627551496029
# Percent Return: -0.12633679571071005
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.2
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 74
# Total Bet: 49.73660558462143
# Profit: -7.083473742306232
# Percent Return: -0.14241972605578143
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.3000000000000003
# Pred Threshold: 0.1
# Number of Bets Placed: 177
# Total Bet: 71.51126603037119
# Profit: -2.0798808124661443
# Percent Return: -0.02908465935399338
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.3000000000000003
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 142
# Total Bet: 67.1165819466114
# Profit: -2.244931920468807
# Percent Return: -0.0334482456549197
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.3000000000000003
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 123
# Total Bet: 63.91912530362606
# Profit: -2.459398659914731
# Percent Return: -0.038476725834907695
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.3000000000000003
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 107
# Total Bet: 60.27241677045822
# Profit: -1.7579716676473625
# Percent Return: -0.029167101003140967
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.3000000000000003
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 93
# Total Bet: 56.45087879896164
# Profit: -7.620567386150358
# Percent Return: -0.13499466347174974
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.3000000000000003
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 87
# Total Bet: 54.57718503475189
# Profit: -7.408339821398258
# Percent Return: -0.1357405996055131
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.3000000000000003
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 74
# Total Bet: 49.73660558462143
# Profit: -7.083473742306232
# Percent Return: -0.14241972605578143
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.4000000000000004
# Pred Threshold: 0.1
# Number of Bets Placed: 162
# Total Bet: 64.46402315050364
# Profit: -1.2609944419562804
# Percent Return: -0.01956121229064849
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.4000000000000004
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 128
# Total Bet: 60.206009924411774
# Profit: -1.5627164076268676
# Percent Return: -0.025956153041678847
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 2.4000000000000004
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 112
# Total Bet: 57.51531381905079
# Profit: -1.5179591773450378
# Percent Return: -0.026392261061474805
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 2.4000000000000004
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 96
# Total Bet: 53.86860528588295
# Profit: -0.8165321850776673
# Percent Return: -0.015157849005822533
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.4000000000000004
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 96
# Total Bet: 53.86860528588295
# Profit: -0.8165321850776673
# Percent Return: -0.015157849005822533
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.4000000000000004
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 82
# Total Bet: 50.04706731438637
# Profit: -6.679127903580665
# Percent Return: -0.133456928887034
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.4000000000000004
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 77
# Total Bet: 48.49113783240318
# Profit: -6.022030343711376
# Percent Return: -0.12418826641117257
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.4000000000000004
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 66
# Total Bet: 44.36578753590584
# Profit: -4.734777739346026
# Percent Return: -0.10672137253315082
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.5
# Pred Threshold: 0.1
# Number of Bets Placed: 147
# Total Bet: 61.53686226904392
# Profit: -1.9680977194011218
# Percent Return: -0.0319824191034708
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.5
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 119
# Total Bet: 58.05628299713135
# Profit: -2.0744017571210867
# Percent Return: -0.03573087442100946
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.5
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 105
# Total Bet: 55.68311481177807
# Profit: -2.3471724468469635
# Percent Return: -0.042152319509800314
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.5
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 94
# Total Bet: 53.20302101969719
# Profit: -1.1217827105522158
# Percent Return: -0.021084943844389994
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.5
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 81
# Total Bet: 49.658733397722244
# Profit: -7.26162877857685
# Percent Return: -0.14623064830143107
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 2.5
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 76
# Total Bet: 48.10280391573906
# Profit: -6.604531218707561
# Percent Return: -0.13730033763263816
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.5
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 66
# Total Bet: 44.36578753590584
# Profit: -4.734777739346026
# Percent Return: -0.10672137253315082
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.6
# Pred Threshold: 0.1
# Number of Bets Placed: 136
# Total Bet: 55.99150440841913
# Profit: -1.2557488955557337
# Percent Return: -0.02242748982766953
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.6
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 110
# Total Bet: 52.750117629766464
# Profit: -1.601245426535607
# Percent Return: -0.030355295845483334
# 32/32 [==============================] - 0s 4ms/step
# Odds Threshold: 2.6
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 96
# Total Bet: 50.376949444413185
# Profit: -1.874016116261483
# Percent Return: -0.03719987289681574
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.6
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 87
# Total Bet: 48.3598410487175
# Profit: -0.5287043023109433
# Percent Return: -0.0109327138147193
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.6
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 87
# Total Bet: 48.3598410487175
# Profit: -0.5287043023109433
# Percent Return: -0.0109327138147193
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.6
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 75
# Total Bet: 45.11554828286171
# Profit: -6.968545226454734
# Percent Return: -0.1544599476607029
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.6
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 70
# Total Bet: 43.559618800878525
# Profit: -6.311447666585445
# Percent Return: -0.14489216940663754
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.6
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 60
# Total Bet: 39.8226024210453
# Profit: -4.44169418722391
# Percent Return: -0.1115370145893976
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.1
# Number of Bets Placed: 127
# Total Bet: 53.11326955258846
# Profit: 0.4268202568590638
# Percent Return: 0.008036038083410793
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.1
# Number of Bets Placed: 127
# Total Bet: 53.11326955258846
# Profit: 0.4268202568590638
# Percent Return: 0.008036038083410793
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 102
# Total Bet: 49.9834606051445
# Profit: -0.03025410532951267
# Percent Return: -0.0006052823266582465
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 90
# Total Bet: 47.92501902580261
# Profit: -0.17974028497934302
# Percent Return: -0.0037504478586137162
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 82
# Total Bet: 46.144010961055756
# Profit: 0.9294711980223651
# Percent Return: 0.02014283497823396
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 82
# Total Bet: 46.144010961055756
# Profit: 0.9294711980223651
# Percent Return: 0.02014283497823396
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 72
# Total Bet: 43.454637229442596
# Profit: -5.307634173035621
# Percent Return: -0.12214195104221108
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 67
# Total Bet: 41.89870774745941
# Profit: -4.650536613166332
# Percent Return: -0.11099475051109002
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 2.7
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 57
# Total Bet: 38.16169136762619
# Profit: -2.780783133804797
# Percent Return: -0.0728684456623384
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 2.8000000000000003
# Pred Threshold: 0.1
# Number of Bets Placed: 118
# Total Bet: 49.24761605262756
# Profit: -0.8378770641982555
# Percent Return: -0.017013555809541593
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.8000000000000003
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 94
# Total Bet: 46.258757427334785
# Profit: -1.0511073690652841
# Percent Return: -0.022722343346909136
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.8000000000000003
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 82
# Total Bet: 44.2003158479929
# Profit: -1.2005935487151156
# Percent Return: -0.027162555870505926
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.8000000000000003
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 75
# Total Bet: 42.66017508506775
# Profit: -0.33224936753511447
# Percent Return: -0.007788279510634522
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.8000000000000003
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 67
# Total Bet: 40.47333359718323
# Profit: -5.684863408207893
# Percent Return: -0.14045948042697268
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.8000000000000003
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 62
# Total Bet: 38.91740411520004
# Profit: -5.027765848338604
# Percent Return: -0.12919067863457265
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.8000000000000003
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 53
# Total Bet: 35.538439095020294
# Profit: -3.5160637286305425
# Percent Return: -0.09893692064610736
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.9000000000000004
# Pred Threshold: 0.1
# Number of Bets Placed: 111
# Total Bet: 45.092402786016464
# Profit: -2.2644767342507843
# Percent Return: -0.05021858659865022
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.9000000000000004
# Pred Threshold: 0.15000000000000002
# Number of Bets Placed: 87
# Total Bet: 42.103544160723686
# Profit: -2.477707039117814
# Percent Return: -0.05884794471599719
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.9000000000000004
# Pred Threshold: 0.20000000000000004
# Number of Bets Placed: 76
# Total Bet: 40.24236299097538
# Profit: -2.824453628361226
# Percent Return: -0.07018607801422169
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.9000000000000004
# Pred Threshold: 0.25000000000000006
# Number of Bets Placed: 69
# Total Bet: 38.70222222805023
# Profit: -1.9561094471812246
# Percent Return: -0.05054256150086116
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.9000000000000004
# Pred Threshold: 0.30000000000000004
# Number of Bets Placed: 61
# Total Bet: 36.51538074016571
# Profit: -7.308723487854003
# Percent Return: -0.20015465646821667
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.9000000000000004
# Pred Threshold: 0.3500000000000001
# Number of Bets Placed: 56
# Total Bet: 34.959451258182526
# Profit: -6.651625927984714
# Percent Return: -0.1902668860234999
# 32/32 [==============================] - 0s 2ms/step
# Odds Threshold: 2.9000000000000004
# Pred Threshold: 0.40000000000000013
# Number of Bets Placed: 47
# Total Bet: 31.580486238002777
# Profit: -5.139923808276652
# Percent Return: -0.16275632267154455
# best odds thresh: 2.7
# best pred thresh: 0.25000000000000006
# max_return: 16.51712468215185

# %%
#profit_betting(0,0.1,model.predict(X_test),y_test2,betting_function)
# Out:
# 32/32 [==============================] - 0s 3ms/step
# Odds Threshold: 0
# Pred Threshold: 0.1
# Number of Bets Placed: 90
# Total Bet: 55.88256438821554
# Profit: 7.6298290774317
# Percent Return: 0.1365332668777933
# 122.87994019001397

# %%
#model.save('nba_model.h5')

# %%
from keras.layers import Input
from keras.layers import BatchNormalization
from keras.layers import Dropout
from keras.layers import Dense
from keras import Model
def get_model(input_dim, output_dim, base=1000, multiplier=0.25, p=0.2,lr = 0.0001):
    inputs = Input(shape=(input_dim,))
    l = BatchNormalization()(inputs)
    l = Dropout(p)(l)
    n = base
    l = Dense(n, activation='relu')(l)
    l = BatchNormalization()(l)
    l = Dropout(p)(l)
    n = int((n * multiplier))
    l = Dense(n, activation='relu')(l)
    l = BatchNormalization()(l)
    l = Dropout(p)(l)
    n = int(n * multiplier)
    l = Dense(n, activation='relu')(l)
    outputs = Dense(output_dim, activation='softmax')(l)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr), loss=profit_loss)
    return model

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
#import kerastuner as kt
def train(model,X_train,y_train,val_split,ep,bs):
    history = model.fit(X_train,y_train,validation_split = val_split,epochs = ep, batch_size = bs)

# %%
#reg15 = pd.read_csv('NBA_DATA/reg15.csv')
#misc15 = pd.read_csv('NBA_DATA/misc15.csv')
#adv15 = pd.read_csv('NBA_DATA/adv15.csv')
#four15 = pd.read_csv('NBA_DATA/four15.csv')
reg16 = pd.read_csv('NBA_DATA/reg16.csv')
misc16 = pd.read_csv('NBA_DATA/misc16.csv')
adv16 = pd.read_csv('NBA_DATA/adv16.csv')
four16 = pd.read_csv('NBA_DATA/four16.csv')
reg17 = pd.read_csv('NBA_DATA/reg17.csv')
misc17 = pd.read_csv('NBA_DATA/misc17.csv')
adv17 = pd.read_csv('NBA_DATA/adv17.csv')
four17 = pd.read_csv('NBA_DATA/four17.csv')
reg18 = pd.read_csv('NBA_DATA/reg18.csv')
misc18 = pd.read_csv('NBA_DATA/misc18.csv')
adv18 = pd.read_csv('NBA_DATA/adv18.csv')
four18 = pd.read_csv('NBA_DATA/four18.csv')
reg19 = pd.read_csv('NBA_DATA/reg19.csv')
misc19 = pd.read_csv('NBA_DATA/misc19.csv')
adv19 = pd.read_csv('NBA_DATA/adv19.csv')
four19 = pd.read_csv('NBA_DATA/four19.csv')

team_ids = reg16.TEAM_ID.value_counts().index

#total15 = get_features(reg15,misc15,adv15,four15)
total16 = get_features(reg16,misc16,adv16,four16)
total17 = get_features(reg17,misc17,adv17,four17)
total18 = get_features(reg18,misc18,adv18,four18)
total19 = get_features(reg19,misc19,adv19,four19)
#total22 = get_features(current,misc22,adv22,four22)

features = [total16,total17,total18]


#vegas15 = pd.read_csv('vegas/2015-16/vegas.txt',sep = ',')
vegas16 = pd.read_csv('vegas/2016-17/vegas.txt',sep = ',')
vegas17 = pd.read_csv('vegas/2017-18/vegas.txt',sep = ',')
vegas18 = pd.read_csv('vegas/2018-19/vegas.txt',sep = ',')

targets = [vegas16,vegas17,vegas18]
#test_targ = [vegas15]

sixteen_eighteen = get_targets_ML(features,targets)
#test = get_targets_ML(test_features,test_targ)

X_train = sixteen_eighteen[0].iloc[0:4500,:]
X_test = sixteen_eighteen[0].iloc[4500:,:]

#sixteen_eighteen[1]['prob_a'] = 1/(sixteen_eighteen[1]['odds_a'])
y = sixteen_eighteen[1][['odds_a','a_win','odds_b']]
y_train1 = y.iloc[0:4500,:]
y_test1 = y.iloc[4500:,:]
y_train2 = y.iloc[0:4500,:]
y_test2 = y.iloc[4500:,:]

#nba_teams = ['Cleveland Cavaliers','Boston Celtics','Golden State Warriors','Houston Rockets','Utah Jazz'
 #            ,'Philadelphia 76ers','Toronto Raptors','New Orleans Pelicans','Washington Wizards','Miami Heat'
  #          ,'Milwaukee Bucks','Indiana Pacers','Oklahoma City Thunder','San Antonio Spurs','Portland Trail Blazers',
   #          'Minnesota Timberwolves','Chicago Bulls','Dallas Mavericks','Sacramento Kings','Los Angeles Lakers'
    ##       ,'Charlotte Hornets','Atlanta Hawks','Phoenix Suns','Brooklyn Nets']

#y_train1['odds_a'] = 1 / (y_train1['prob_a'])
#y_test1['odds_a'] = 1 / (y_test1['prob_a'])

#y_train2['odds_a'] = 1 / (y_train2['prob_a'])
#y_test2['odds_a'] = 1 / (y_test2['prob_a'])

#y_train2['odds_b'] = 1/(1-y_train2['prob_a'])
#y_test2['odds_b'] = 1/(1-y_test2['prob_a'])

y_train2['b_win'] = abs(1-y_train2['a_win'])
y_test2['b_win'] = abs(1-y_test2['a_win'])

y_train2['no_bet'] = 0
y_test2['no_bet'] = 0

X_train = order_features(X_train)
X_test = order_features(X_test)




y_train2 = y_train2.loc[:,['a_win','b_win','no_bet','odds_a','odds_b']]
y_test2 = y_test2.loc[:,['a_win','b_win','no_bet','odds_a','odds_b']]

#y_train2 = y_train2.drop(columns = ['prob_a'])
#y_test2 = y_test2.drop(columns = ['prob_a'])
# Out:
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
# ...
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/2409799907.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   features[new_col_name] = features.groupby('TEAM_ID')[columnName].apply(lambda x: x.shift().expanding().median())
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(merged)
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(merged)
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(merged)
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Odds_A'] = odds_convert(y['Pinnacle_ML_A'])
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['Odds_B'] = odds_convert(y['Pinnacle_ML_B'])
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/1838762224.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['y_true'] = y.apply(lambda row : get_y_true(row['Result_A'],
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/402716704.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train2['b_win'] = abs(1-y_train2['a_win'])
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/402716704.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test2['b_win'] = abs(1-y_test2['a_win'])
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/402716704.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_train2['no_bet'] = 0
# /var/folders/kp/6k7tyx6n3fz8w9_827mz4hxh0000gn/T/ipykernel_7688/402716704.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_test2['no_bet'] = 0

# %%
model = get_model(96,3,96,0.5,0.5,0.0001)
train(model,X_train,y_train2,0.2,100,50)
# Out:
# Epoch 1/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0277 - val_loss: 0.0227
# Epoch 2/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0099 - val_loss: 0.0233
# Epoch 3/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0231 - val_loss: 0.0229
# Epoch 4/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0190 - val_loss: 0.0223
# Epoch 5/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.0045 - val_loss: 0.0232
# Epoch 6/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0198 - val_loss: 0.0237
# Epoch 7/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0446 - val_loss: 0.0246
# Epoch 8/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0307 - val_loss: 0.0244
# Epoch 9/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0353 - val_loss: 0.0251
# Epoch 10/100
# 72/72 [==============================] - 0s 7ms/step - loss: -0.0280 - val_loss: 0.0259
# Epoch 11/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0199 - val_loss: 0.0260
# Epoch 12/100
# 72/72 [==============================] - 0s 6ms/step - loss: -0.0260 - val_loss: 0.0260
# Epoch 13/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0296 - val_loss: 0.0258
# Epoch 14/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0167 - val_loss: 0.0255
# Epoch 15/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0343 - val_loss: 0.0251
# Epoch 16/100
# 72/72 [==============================] - 0s 6ms/step - loss: -0.0188 - val_loss: 0.0250
# Epoch 17/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0265 - val_loss: 0.0247
# Epoch 18/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0157 - val_loss: 0.0252
# Epoch 19/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0152 - val_loss: 0.0257
# Epoch 20/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0366 - val_loss: 0.0254
# Epoch 21/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0298 - val_loss: 0.0262
# Epoch 22/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0335 - val_loss: 0.0259
# Epoch 23/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0260 - val_loss: 0.0263
# Epoch 24/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0283 - val_loss: 0.0270
# Epoch 25/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0329 - val_loss: 0.0273
# Epoch 26/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0213 - val_loss: 0.0273
# Epoch 27/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0334 - val_loss: 0.0276
# Epoch 28/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0489 - val_loss: 0.0279
# Epoch 29/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0244 - val_loss: 0.0278
# Epoch 30/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0155 - val_loss: 0.0278
# Epoch 31/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0317 - val_loss: 0.0281
# Epoch 32/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0319 - val_loss: 0.0282
# Epoch 33/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0258 - val_loss: 0.0290
# Epoch 34/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0337 - val_loss: 0.0290
# Epoch 35/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0158 - val_loss: 0.0282
# Epoch 36/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0205 - val_loss: 0.0285
# Epoch 37/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0339 - val_loss: 0.0284
# Epoch 38/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0464 - val_loss: 0.0288
# Epoch 39/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0253 - val_loss: 0.0287
# Epoch 40/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0356 - val_loss: 0.0283
# Epoch 41/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0245 - val_loss: 0.0294
# Epoch 42/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0580 - val_loss: 0.0297
# Epoch 43/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0544 - val_loss: 0.0297
# Epoch 44/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0310 - val_loss: 0.0301
# Epoch 45/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0439 - val_loss: 0.0300
# Epoch 46/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0467 - val_loss: 0.0302
# Epoch 47/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0247 - val_loss: 0.0306
# Epoch 48/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0431 - val_loss: 0.0312
# Epoch 49/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0438 - val_loss: 0.0315
# Epoch 50/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0330 - val_loss: 0.0316
# Epoch 51/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0142 - val_loss: 0.0320
# Epoch 52/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0401 - val_loss: 0.0325
# Epoch 53/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0242 - val_loss: 0.0326
# Epoch 54/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0415 - val_loss: 0.0327
# Epoch 55/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0506 - val_loss: 0.0343
# Epoch 56/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0444 - val_loss: 0.0346
# Epoch 57/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0672 - val_loss: 0.0347
# Epoch 58/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0415 - val_loss: 0.0349
# Epoch 59/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0364 - val_loss: 0.0357
# Epoch 60/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0519 - val_loss: 0.0358
# Epoch 61/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0419 - val_loss: 0.0361
# Epoch 62/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0358 - val_loss: 0.0365
# Epoch 63/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0404 - val_loss: 0.0365
# Epoch 64/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0503 - val_loss: 0.0373
# Epoch 65/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0506 - val_loss: 0.0379
# Epoch 66/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0362 - val_loss: 0.0380
# Epoch 67/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0404 - val_loss: 0.0382
# Epoch 68/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0349 - val_loss: 0.0386
# Epoch 69/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0375 - val_loss: 0.0392
# Epoch 70/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0490 - val_loss: 0.0392
# Epoch 71/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0317 - val_loss: 0.0390
# Epoch 72/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0467 - val_loss: 0.0392
# Epoch 73/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0270 - val_loss: 0.0394
# Epoch 74/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0463 - val_loss: 0.0394
# Epoch 75/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0395 - val_loss: 0.0398
# Epoch 76/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0399 - val_loss: 0.0398
# Epoch 77/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0488 - val_loss: 0.0397
# Epoch 78/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0417 - val_loss: 0.0393
# Epoch 79/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0228 - val_loss: 0.0390
# Epoch 80/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0430 - val_loss: 0.0391
# Epoch 81/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0349 - val_loss: 0.0396
# Epoch 82/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0341 - val_loss: 0.0390
# Epoch 83/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0513 - val_loss: 0.0389
# Epoch 84/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0291 - val_loss: 0.0389
# Epoch 85/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0544 - val_loss: 0.0385
# Epoch 86/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0379 - val_loss: 0.0381
# Epoch 87/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0609 - val_loss: 0.0383
# Epoch 88/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0392 - val_loss: 0.0385
# Epoch 89/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0393 - val_loss: 0.0389
# Epoch 90/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0725 - val_loss: 0.0397
# Epoch 91/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0455 - val_loss: 0.0396
# Epoch 92/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0477 - val_loss: 0.0400
# Epoch 93/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0373 - val_loss: 0.0401
# Epoch 94/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0422 - val_loss: 0.0402
# Epoch 95/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0471 - val_loss: 0.0403
# Epoch 96/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0497 - val_loss: 0.0401
# Epoch 97/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0443 - val_loss: 0.0403
# Epoch 98/100
# 72/72 [==============================] - 0s 4ms/step - loss: -0.0413 - val_loss: 0.0403
# Epoch 99/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0520 - val_loss: 0.0410
# Epoch 100/100
# 72/72 [==============================] - 0s 5ms/step - loss: -0.0477 - val_loss: 0.0404

# %%
def balance_check(predictions):
    averageA = 0
    averageB = 0
    for i in predictions:
        averageA += i[0]
        averageB += i[1]
    print(str(averageB - averageA ))

# %%
balance_check(model.predict(X_test))
# Out:
# 32/32 [==============================] - 0s 1ms/step
# 56.971939268570594

# %%
def check_column(train, column_name):
    column_A = column_name + '_A'
    column_B = column_name + '_B'
    frame = train[[column_A,column_B]]
    sum_A = 0
    sum_B = 0
    for i in range(frame.shape[0]):
        sum_A += frame.iloc[i,0]
        sum_B += frame.iloc[i,1]
    print('sum_A: ' + str(sum_A))
    print('sum_B: ' + str(sum_B))
    return(abs(sum_A - sum_B) < 0.1)

# %%
def check_train(train):
    for columnName in train:
        columnName = columnName[:-2]
        check_column(X_train,columnName)

# %%
check_train(X_train)
# Out:
# sum_A: 2057.760999999994
# sum_B: 2057.7609999999945
# sum_A: 1602.5265000000168
# sum_B: 1602.5265000000168
# sum_A: 3478.5705000000285
# sum_B: 3478.570500000029
# sum_A: 9893.667504642914
# sum_B: 9893.667504642912
# sum_A: 3662.559211251298
# sum_B: 3662.5592112512977
# sum_A: 8007.724012970529
# sum_B: 8007.724012970528
# sum_A: 947.197620806472
# sum_B: 947.1976208064718
# sum_A: 2642.315248918957
# sum_B: 2642.315248918957
# sum_A: 1621.351461333878
# sum_B: 1621.3514613338782
# sum_A: 2112.227041738095
# sum_B: 2112.2270417380946
# sum_A: 931.7214588045094
# sum_B: 931.7214588045094
# sum_A: 3137.588932320165
# sum_B: 3137.588932320165
# sum_A: 4069.310391124672
# sum_B: 4069.310391124672
# sum_A: 2126.3519750269597
# sum_B: 2126.3519750269597
# sum_A: 723.6094567685695
# sum_B: 723.6094567685695
# sum_A: 453.6075905100528
# sum_B: 453.6075905100528
# sum_A: 1287.1917956435123
# sum_B: 1287.191795643512
# sum_A: 1895.564179261716
# sum_B: 1895.564179261716
# sum_A: 0.9238727500617508
# sum_B: 0.9238727500617498
# sum_A: 2250
# sum_B: 2250
# sum_A: 476928.6000000007
# sum_B: 476928.6000000006
# sum_A: 485278.8499999985
# sum_B: 485278.8499999986
# sum_A: 476576.04999999714
# sum_B: 476576.04999999714
# sum_A: 484864.95000000176
# sum_B: 484864.95000000176
# sum_A: 251.30000000000007
# sum_B: 251.3
# sum_A: 342.34999999999945
# sum_B: 342.3499999999994
# sum_A: 2623.5034999999793
# sum_B: 2623.503499999979
# sum_A: 7209.125000000046
# sum_B: 7209.125000000046
# sum_A: 76703.30000000013
# sum_B: 76703.30000000013
# sum_A: 1217.9290000000053
# sum_B: 1217.9290000000053
# sum_A: 3281.849499999979
# sum_B: 3281.8494999999793
# sum_A: 2250.5450000000014
# sum_B: 2250.545000000001
# sum_A: 63961.398500000076
# sum_B: 63961.398500000076
# sum_A: 65028.099999999664
# sum_B: 65028.09999999966
# sum_A: 2328.0099999999884
# sum_B: 2328.009999999988
# sum_A: 2492.3780000000006
# sum_B: 2492.3780000000006
# sum_A: 4500.0
# sum_B: 4500.0
# sum_A: 893.7234999999413
# sum_B: 893.7234999999413
# sum_A: 448558.72499999974
# sum_B: 448558.7249999998
# sum_A: 441142.2400000001
# sum_B: 441142.2400000001
# sum_A: 367618.55500000145
# sum_B: 367618.5550000014
# sum_A: 442578.5
# sum_B: 442578.5
# sum_A: 2248.513999999986
# sum_B: 2248.513999999986
# sum_A: 1165.383500000004
# sum_B: 1165.3835000000042
# sum_A: 2323.411500000001
# sum_B: 2323.411500000001
# sum_A: 1164.3460000000032
# sum_B: 1164.3460000000032
# sum_A: 639.765999999998
# sum_B: 639.7659999999979
# sum_A: 1214.0719999999903
# sum_B: 1214.0719999999903
# sum_A: 2057.760999999994
# sum_B: 2057.7609999999945
# sum_A: 1602.5265000000168
# sum_B: 1602.5265000000168
# sum_A: 3478.5705000000285
# sum_B: 3478.570500000029
# sum_A: 9893.667504642914
# sum_B: 9893.667504642912
# sum_A: 3662.559211251298
# sum_B: 3662.5592112512977
# sum_A: 8007.724012970529
# sum_B: 8007.724012970528
# sum_A: 947.197620806472
# sum_B: 947.1976208064718
# sum_A: 2642.315248918957
# sum_B: 2642.315248918957
# sum_A: 1621.351461333878
# sum_B: 1621.3514613338782
# sum_A: 2112.227041738095
# sum_B: 2112.2270417380946
# sum_A: 931.7214588045094
# sum_B: 931.7214588045094
# sum_A: 3137.588932320165
# sum_B: 3137.588932320165
# sum_A: 4069.310391124672
# sum_B: 4069.310391124672
# sum_A: 2126.3519750269597
# sum_B: 2126.3519750269597
# sum_A: 723.6094567685695
# sum_B: 723.6094567685695
# sum_A: 453.6075905100528
# sum_B: 453.6075905100528
# sum_A: 1287.1917956435123
# sum_B: 1287.191795643512
# sum_A: 1895.564179261716
# sum_B: 1895.564179261716
# sum_A: 0.9238727500617508
# sum_B: 0.9238727500617498
# sum_A: 2250
# sum_B: 2250
# sum_A: 476928.6000000007
# sum_B: 476928.6000000006
# sum_A: 485278.8499999985
# sum_B: 485278.8499999986
# sum_A: 476576.04999999714
# sum_B: 476576.04999999714
# sum_A: 484864.95000000176
# sum_B: 484864.95000000176
# sum_A: 251.30000000000007
# sum_B: 251.3
# sum_A: 342.34999999999945
# sum_B: 342.3499999999994
# sum_A: 2623.5034999999793
# sum_B: 2623.503499999979
# sum_A: 7209.125000000046
# sum_B: 7209.125000000046
# sum_A: 76703.30000000013
# sum_B: 76703.30000000013
# sum_A: 1217.9290000000053
# sum_B: 1217.9290000000053
# sum_A: 3281.849499999979
# sum_B: 3281.8494999999793
# sum_A: 2250.5450000000014
# sum_B: 2250.545000000001
# sum_A: 63961.398500000076
# sum_B: 63961.398500000076
# sum_A: 65028.099999999664
# sum_B: 65028.09999999966
# sum_A: 2328.0099999999884
# sum_B: 2328.009999999988
# sum_A: 2492.3780000000006
# sum_B: 2492.3780000000006
# sum_A: 4500.0
# sum_B: 4500.0
# sum_A: 893.7234999999413
# sum_B: 893.7234999999413
# sum_A: 448558.72499999974
# sum_B: 448558.7249999998
# sum_A: 441142.2400000001
# sum_B: 441142.2400000001
# sum_A: 367618.55500000145
# sum_B: 367618.5550000014
# sum_A: 442578.5
# sum_B: 442578.5
# sum_A: 2248.513999999986
# sum_B: 2248.513999999986
# sum_A: 1165.383500000004
# sum_B: 1165.3835000000042
# sum_A: 2323.411500000001
# sum_B: 2323.411500000001
# sum_A: 1164.3460000000032
# sum_B: 1164.3460000000032
# sum_A: 639.765999999998
# sum_B: 639.7659999999979
# sum_A: 1214.0719999999903
# sum_B: 1214.0719999999903
